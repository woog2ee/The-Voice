# %% [markdown]
# ### 기본 세팅

# %%
import numpy as np
import pandas as pd
import pickle

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression    
from sklearn.naive_bayes import GaussianNB          
from sklearn.ensemble import RandomForestClassifier    

from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn.metrics import recall_score
from sklearn.metrics import precision_score
from sklearn.model_selection import KFold

# %%
# 임베딩 배열을 데이터프레임으로 변환
def make_df(data):
    
    array = data[0]     # 첫번째 array
    error = []          # 에러 인덱스 리스트
    

    for index in range(len(data)-1):
        plus_array = data[index+1]     # 추가할 array
        try:
            array = np.concatenate((array, plus_array), axis=0) 
        except:
            print(index+1, '번 인덱스 오류 처리 완료')
            error.append(index+1)     # 에러 인덱스 저장
            
        # 201건부터는 모두 보이스피싱 텍스트 임베딩값
        # 보이스피싱 여부를 붙이고자 phishing_check로 인덱스 지정
        if (index+1) == 199:
            phishing_check = array.shape[0] + 1

    
    # 데이터프레임 변환 및 레이블 지정
    df = pd.DataFrame(array)
    df['phishing'] = 0                        # 상담 텍스트 임베딩값
    df.loc[phishing_check:,'phishing'] = 1    # 보이스파싱 텍스트 임베딩값
    return df

# %% [markdown]
# ### train, validation 분할

# %%
def data_split(df):
    feature = df.iloc[:,:-1]      # 피처 칼럼: 예측에 사용되는 데이터
    target  = df['phishing']      # 타겟 칼럼: 예측(분류) 대상 데이터
    x_train, x_valid, y_train, y_valid = train_test_split(feature, target, test_size=0.2,
                                                          shuffle=True,      
                                                          stratify=target,  
                                                          random_state=1234) 
    return x_train, x_valid, y_train, y_valid, feature, target

# %% [markdown]
# ### 분류 모델 세팅

# %%
# 분류 score 계산
def score(pred, y_test):
    print(' accuracy  : ', accuracy_score(y_test, pred))
    print(' f1-score  : ', f1_score(y_test, pred))
    print(' recall    : ', recall_score(y_test, pred))
    print(' precision : ', precision_score(y_test, pred))
    return accuracy_score(y_test, pred), f1_score(y_test, pred), recall_score(y_test, pred), precision_score(y_test, pred)

# %%
# score result에 결과 추가
def result_append(score_result, scores):
    score_result = score_result.append(pd.Series(scores, index=score_result.columns), ignore_index=True)
    return score_result

# %%
# 최종 결과 리스트
score_result = pd.DataFrame(columns=['logistic_Acc', 'logistic_F1', 'logistic_Rec', 'logistic_Pre', 
                                     'naivebayes_Acc', 'naivebayes_F1', 'naivebayes_Rec', 'naivebayes_Pre',
                                     'randomforest_Acc', 'logistic_F1', 'naivebayes_Rec', 'randomforest_Pre',
                                     'logistic_5fold_Acc', 'logistic_5fold_F1', 'logistic_5fold_Rec', 'logistic_5fold_Pre',
                                     'naivebayes_5Fold_Acc', 'naivebayes_5Fold_F1', 'naivebayes_5Fold_Rec', 'naivebayes_5Fold_Pre',
                                     'randomforest_5Fold_Acc', 'randomforest_5Fold_F1', 'randomforest_5Fold_Rec', 'randomforest_5Fold_Pre'])

# %% [markdown]
# ### Logistic Regression

# %%
def logistic_reg(x_train, y_train, x_valid, y_valid):
    
    # 모델 분류 수행
    reg = LogisticRegression(random_state=0, max_iter=500)
    reg.fit(x_train, y_train)
    pred = reg.predict(x_valid)
    
    
    # 분류 score 계산
    accuracy, f1_score, recall, precision = score(pred, y_valid)
    return accuracy, f1_score, recall, precision

# %% [markdown]
# ### Naive Bayes Classification

# %%
def naivebayes_clf(x_train, y_train, x_valid, y_valid):
    
    # 모델 분류 수행
    gnb = GaussianNB()
    gnb.fit(x_train, y_train)
    pred = gnb.predict(x_valid)
    
    
    # 분류 score 계산
    accuracy, f1_score, recall, precision = score(pred, y_valid)
    return accuracy, f1_score, recall, precision

# %% [markdown]
# ### RandomForest Classification

# %%
def randomforest_clf(x_train, y_train, x_valid, y_valid):
    
    # 모델 분류 수행
    clf = RandomForestClassifier(max_depth=16, random_state=0)
    clf.fit(x_train, y_train)
    pred = clf.predict(x_valid)
    
    
    # 분류 score 계산
    accuracy, f1_score, recall, precision = score(pred, y_valid)
    return accuracy, f1_score, recall, precision

# %% [markdown]
# ### K-Fold Cross Validation

# %%
def kfold_clf(model, feature, target):

    # 5개 폴드세트를 분리하는 kFold 객체와
    # 폴드세트별 score 값을 담을 리스트
    kfold = KFold(n_splits=5, random_state=0, shuffle=True)
    cv_accuracy = []
    cv_f1score = []
    cv_precision = []
    cv_recall = []
    
    
    n_iter = 0   
    for train_index, validate_index in kfold.split(feature):
        # 데이터셋 지정
        X_train, X_valid = feature.iloc[train_index,:], feature.iloc[validate_index,:]
        y_train, y_valid = target[train_index], target[validate_index]
        
        
        # 학습 및 예측
        model.fit(X_train, y_train)
        pred = model.predict(X_valid)
        n_iter += 1
        
        
        # 데이터 size 확인
        train_size = X_train.shape[0]
        test_size = X_valid.shape[0]
        print(f' ========= {n_iter} =========')
        
        
        # iteration마다 score 측정
        accuracy,f1score,precision, recall = score(pred, y_valid)   
        
        
        # iteration 별 score 값 저장
        cv_accuracy.append(accuracy)
        cv_f1score.append(f1score)
        cv_precision.append(precision)
        cv_recall.append(recall)
        
        
    # 개별 iteration별 정확도를 합한 평균 계산
    print(' ======== 최종 ========')
    print(' 평균검증 정확도   : ', np.mean(cv_accuracy))
    print(' 평균검증 f1-score : ', np.mean(cv_f1score))
    print(' 평균검증 정밀도   : ', np.mean(cv_precision))
    print(' 평균검증 재현율   : ', np.mean(cv_recall))
    print(' \n')
    return np.mean(cv_accuracy), np.mean(cv_f1score), np.mean(cv_precision), np.mean(cv_recall)

# %% [markdown]
# ### 전체 분류 모델 통합

# %%
def total_model(data):
    
    # 임베딩 배열을 데이터프레임으로 전환
    df = make_df(data)
    # train / test 데이터 분할
    x_train, x_valid, y_train, y_valid, feature, target = data_split(df)
    # 리턴할 점수 리스트
    score_list = []
    print(' 데이터 가공 완료\n')
    
    
    # Logistic Regression
    print('      ----------    Logistic Regression Result    ----------      ')
    logi1, logi2, logi3, logi4 = logistic_reg(x_train, y_train, x_valid, y_valid)
    score_list += [logi1, logi2, logi3, logi4]
    
    
    # Naive Bayes Classification
    print('      ---------- Naive Bayes Classification Result ----------      ')
    naive1, naive2, naive3, naive4 = naivebayes_clf(x_train, y_train, x_valid, y_valid)
    score_list += [naive1, naive2, naive3, naive4]
    
    
    # RandomForest Classification
    print('      ---------- RandomForest Classifcation Result ----------      ')
    rf1, rf2, rf3, rf4 = randomforest_clf(x_train, y_train, x_valid, y_valid)
    score_list += [rf1, rf2, rf3, rf4]
    
    
    # 5-Fold Logistic Regression
    print(' \n')
    print('   ----------    [5-Fold] Logistic Regression Result    ----------   ')
    lgb = LogisticRegression(random_state=0, max_iter=500)
    foldlogi1, foldlogi2, foldlogi3, foldlogi4 = kfold_clf(lgb, feature, target)
    score_list += [foldlogi1, foldlogi2, foldlogi3, foldlogi4]
    
    
    # 5-Fold NaiveBayes
    print('   ---------- [5-Fold] Naive Bayes Classification Result ----------   ')
    gnb = GaussianNB()
    foldnb1, foldnb2, foldnb3, foldnb4 = kfold_clf(gnb, feature, target)
    score_list += [foldnb1, foldnb2, foldnb3, foldnb4]
    
    
    # 5-Fold RandomForest Classification 
    print('   ---------- [5-Fold] RandomForest Classifcation Result ----------   ')
    clf = RandomForestClassifier(max_depth=16, random_state=0)
    foldrf1, foldrf2, foldrf3, foldrf4 = kfold_clf(clf, feature, target)
    score_list += [foldrf1, foldrf2, foldrf3, foldrf4]
    return score_list

# %% [markdown]
# ### 모델 이용 데이터셋 분류: original

# %%
# 데이터 로드
origin_2gram = np.load('./save_embeddings/original_2gram_embedding.npy', allow_pickle=True)
origin_3gram = np.load('./save_embeddings/original_3gram_embedding.npy', allow_pickle=True)
origin_4gram = np.load('./save_embeddings/original_4gram_embedding.npy', allow_pickle=True)

# %%
# original_2gram
ori_2g = total_model(origin_2gram)
score_result = result_append(score_result, ori_2g)
# Out:
# 304 번 인덱스 오류 처리 완료
# 330 번 인덱스 오류 처리 완료
# 332 번 인덱스 오류 처리 완료
#  데이터 가공 완료
#
#       ----------    Logistic Regression Result    ----------
#  accuracy  :  0.9263206672845227
#  f1-score  :  0.9268629254829807
#  recall    :  0.9213534522176497
#  precision :  0.9324386857936141
#       ---------- Naive Bayes Classification Result ----------
#  accuracy  :  0.7506950880444856
#  f1-score  :  0.74344301382928
#  recall    :  0.7128486511202561
#  precision :  0.7767812655705032
#       ---------- RandomForest Classifcation Result ----------
#  accuracy  :  0.871177015755329
#  f1-score  :  0.8735213830755232
#  recall    :  0.877914951989026
#  precision :  0.8691715708465368
#
#
#    ----------    [5-Fold] Logistic Regression Result    ----------
#  ========= 1 =========
#  accuracy  :  0.9244670991658943
#  f1-score  :  0.9249884951679705
#  recall    :  0.9186471663619744
#  precision :  0.9314179796107507
#  ========= 2 =========
#  accuracy  :  0.9263206672845227
#  f1-score  :  0.9275956284153004
#  recall    :  0.9280182232346241
#  precision :  0.9271734182976786
#  ========= 3 =========
#  accuracy  :  0.9189063948100092
#  f1-score  :  0.9209932279909707
#  recall    :  0.9193330328977016
#  precision :  0.9226594301221167
#  ========= 4 =========
#  accuracy  :  0.9355885078776645
#  f1-score  :  0.9358856088560885
#  recall    :  0.9354541263254956
#  precision :  0.936317489616982
#  ========= 5 =========
#  accuracy  :  0.9237720111214087
#  f1-score  :  0.9241061130334486
#  recall    :  0.9260286638927415
#  precision :  0.9221915285451197
#  ======== 최종 ========
#  평균검증 정확도   :  0.9258109360518999
#  평균검증 f1-score :  0.9267138146927557
#  평균검증 정밀도   :  0.9254962425425074
#  평균검증 재현율   :  0.9279519692385296
#
#
#    ---------- [5-Fold] Naive Bayes Classification Result ----------
#  ========= 1 =========
#  accuracy  :  0.7465245597775718
#  f1-score  :  0.743192488262911
#  recall    :  0.723491773308958
#  precision :  0.763996138996139
#  ========= 2 =========
#  accuracy  :  0.7562557924003707
#  f1-score  :  0.7504743833017079
#  recall    :  0.7207289293849658
#  precision :  0.7827808015833746
#  ========= 3 =========
#  accuracy  :  0.7437442075996293
#  f1-score  :  0.7396421845574388
#  recall    :  0.7079765660207301
#  precision :  0.7742730409068507
#  ========= 4 =========
#  accuracy  :  0.7414272474513438
#  f1-score  :  0.729126213592233
#  recall    :  0.6924850161364684
#  precision :  0.769861609431061
#  ========= 5 =========
#  accuracy  :  0.745366079703429
#  f1-score  :  0.7375208980176738
#  recall    :  0.713823393435044
#  precision :  0.7628458498023716
#  ======== 최종 ========
#  평균검증 정확도   :  0.7466635773864689
#  평균검증 f1-score :  0.7399912335463928
#  평균검증 정밀도   :  0.7117011356572333
#  평균검증 재현율   :  0.7707514881439594
#
#
#    ---------- [5-Fold] RandomForest Classifcation Result ----------
#  ========= 1 =========
#  accuracy  :  0.8695551436515292
#  f1-score  :  0.8720745285162463
#  recall    :  0.8770566727605119
#  precision :  0.8671486669679168
#  ========= 2 =========
#  accuracy  :  0.8741890639481001
#  f1-score  :  0.8775648252536641
#  recall    :  0.8865603644646924
#  precision :  0.86875
#  ========= 3 =========
#  accuracy  :  0.8621408711770158
#  f1-score  :  0.8663221747921817
#  recall    :  0.8688598467778279
#  precision :  0.8637992831541219
#  ========= 4 =========
#  accuracy  :  0.8734939759036144
#  f1-score  :  0.8743093922651933
#  recall    :  0.8755186721991701
#  precision :  0.8731034482758621
#  ========= 5 =========
#  accuracy  :  0.8716404077849861
#  f1-score  :  0.8733424782807498
#  recall    :  0.8830328247803976
#  precision :  0.8638625056535504
#  ======== 최종 ========
#  평균검증 정확도   :  0.8702038924930493
#  평균검증 f1-score :  0.8727226798216071
#  평균검증 정밀도   :  0.8782056761965199
#  평균검증 재현율   :  0.8673327808102902

# %%
# original_3gram
ori_3g = total_model(origin_3gram)
score_result = result_append(score_result, ori_3g)
# Out:
# 264 번 인덱스 오류 처리 완료
# 304 번 인덱스 오류 처리 완료
# 316 번 인덱스 오류 처리 완료
# 330 번 인덱스 오류 처리 완료
# 332 번 인덱스 오류 처리 완료
# 334 번 인덱스 오류 처리 완료
#  데이터 가공 완료
#
#       ----------    Logistic Regression Result    ----------
#  accuracy  :  0.9621087314662273
#  f1-score  :  0.9627917725907095
#  recall    :  0.9643518518518519
#  precision :  0.9612367328103368
#       ---------- Naive Bayes Classification Result ----------
#  accuracy  :  0.7844198634972935
#  f1-score  :  0.7802303262955854
#  recall    :  0.7527777777777778
#  precision :  0.8097609561752988
#       ---------- RandomForest Classifcation Result ----------
#  accuracy  :  0.9065662508825606
#  f1-score  :  0.9090075636030254
#  recall    :  0.9180555555555555
#  precision :  0.9001361779391739
#
#
#    ----------    [5-Fold] Logistic Regression Result    ----------
#  ========= 1 =========
#  accuracy  :  0.9557542951282655
#  f1-score  :  0.9562179785747554
#  recall    :  0.9606925596630791
#  precision :  0.951784886416319
#  ========= 2 =========
#  accuracy  :  0.9559896446222641
#  f1-score  :  0.9573934837092731
#  recall    :  0.961996336996337
#  precision :  0.9528344671201814
#  ========= 3 =========
#  accuracy  :  0.955743879472693
#  f1-score  :  0.9571167883211679
#  recall    :  0.957553628480146
#  precision :  0.9566803465572276
#  ========= 4 =========
#  accuracy  :  0.963512241054614
#  f1-score  :  0.9638273045507585
#  recall    :  0.9613594040968343
#  precision :  0.9663079082826392
#  ========= 5 =========
#  accuracy  :  0.9613935969868174
#  f1-score  :  0.9615384615384616
#  recall    :  0.9597378277153558
#  precision :  0.9633458646616542
#  ======== 최종 ========
#  평균검증 정확도   :  0.9584787314529308
#  평균검증 f1-score :  0.9592188033388833
#  평균검증 정밀도   :  0.9602679513903503
#  평균검증 재현율   :  0.9581906946076042
#
#
#    ---------- [5-Fold] Naive Bayes Classification Result ----------
#  ========= 1 =========
#  accuracy  :  0.7820663685573076
#  f1-score  :  0.7771896053897979
#  recall    :  0.7557323350491343
#  precision :  0.7999009410599307
#  ========= 2 =========
#  accuracy  :  0.7735937867733584
#  f1-score  :  0.7731132075471698
#  recall    :  0.7504578754578755
#  precision :  0.7971789883268483
#  ========= 3 =========
#  accuracy  :  0.7890772128060264
#  f1-score  :  0.7858508604206501
#  recall    :  0.7503423094477407
#  precision :  0.8248871048670346
#  ========= 4 =========
#  accuracy  :  0.7827212806026366
#  f1-score  :  0.7780716518393843
#  recall    :  0.7532588454376163
#  precision :  0.8045748383888612
#  ========= 5 =========
#  accuracy  :  0.7796610169491526
#  f1-score  :  0.7740222114920329
#  recall    :  0.7504681647940075
#  precision :  0.7991026919242273
#  ======== 최종 ========
#  평균검증 정확도   :  0.7814239331376964
#  평균검증 f1-score :  0.777649507337807
#  평균검증 정밀도   :  0.7520519060372749
#  평균검증 재현율   :  0.8051289129133805
#
#
#    ---------- [5-Fold] RandomForest Classifcation Result ----------
#  ========= 1 =========
#  accuracy  :  0.8922099317486467
#  f1-score  :  0.8947126436781608
#  recall    :  0.9106223678053346
#  precision :  0.8793492995933122
#  ========= 2 =========
#  accuracy  :  0.8952694751706284
#  f1-score  :  0.8987946327041164
#  recall    :  0.9047619047619048
#  precision :  0.8929055580659738
#  ========= 3 =========
#  accuracy  :  0.9093691148775894
#  f1-score  :  0.912797281993205
#  recall    :  0.9196713829301689
#  precision :  0.9060251798561151
#  ========= 4 =========
#  accuracy  :  0.9048964218455744
#  f1-score  :  0.9069981583793738
#  recall    :  0.9171322160148976
#  precision :  0.8970856102003643
#  ========= 5 =========
#  accuracy  :  0.905367231638418
#  f1-score  :  0.9071593533487298
#  recall    :  0.9194756554307116
#  precision :  0.8951686417502279
#  ======== 최종 ========
#  평균검증 정확도   :  0.9014224350561714
#  평균검증 f1-score :  0.904092414020717
#  평균검증 정밀도   :  0.9143327053886035
#  평균검증 재현율   :  0.8941068578931987

# %%
# original_4gram
ori_4g = total_model(origin_4gram)
score_result = result_append(score_result, ori_4g)
# Out:
# 264 번 인덱스 오류 처리 완료
# 291 번 인덱스 오류 처리 완료
# 304 번 인덱스 오류 처리 완료
# 316 번 인덱스 오류 처리 완료
# 330 번 인덱스 오류 처리 완료
# 331 번 인덱스 오류 처리 완료
# 332 번 인덱스 오류 처리 완료
# 334 번 인덱스 오류 처리 완료
#  데이터 가공 완료
#
#       ----------    Logistic Regression Result    ----------
#  accuracy  :  0.9748923959827833
#  f1-score  :  0.9754271003978469
#  recall    :  0.9770276605719643
#  precision :  0.9738317757009346
#       ---------- Naive Bayes Classification Result ----------
#  accuracy  :  0.8142037302725968
#  f1-score  :  0.8144256030570813
#  recall    :  0.7993436474449133
#  precision :  0.8300876338851022
#       ---------- RandomForest Classifcation Result ----------
#  accuracy  :  0.9184600669536107
#  f1-score  :  0.9212289212289213
#  recall    :  0.9348335677449602
#  precision :  0.9080145719489982
#
#
#    ----------    [5-Fold] Logistic Regression Result    ----------
#  ========= 1 =========
#  accuracy  :  0.9727403156384505
#  f1-score  :  0.9730113636363636
#  recall    :  0.9748576850094877
#  precision :  0.97117202268431
#  ========= 2 =========
#  accuracy  :  0.9803921568627451
#  f1-score  :  0.9808946877912396
#  recall    :  0.9795253606328524
#  precision :  0.9822678488100793
#  ========= 3 =========
#  accuracy  :  0.9758430997369051
#  f1-score  :  0.976625781069197
#  recall    :  0.9723502304147466
#  precision :  0.9809390980939098
#  ========= 4 =========
#  accuracy  :  0.9753647452762497
#  f1-score  :  0.9758838679466167
#  recall    :  0.9770276605719643
#  precision :  0.9747427502338635
#  ========= 5 =========
#  accuracy  :  0.9712987323606793
#  f1-score  :  0.9714557564224547
#  recall    :  0.9719181342217992
#  precision :  0.9709938183547313
#  ======== 최종 ========
#  평균검증 정확도   :  0.975127809975006
#  평균검증 f1-score :  0.9755742913731744
#  평균검증 정밀도   :  0.97513581417017
#  평균검증 재현율   :  0.9760231076353788
#
#
#    ---------- [5-Fold] Naive Bayes Classification Result ----------
#  ========= 1 =========
#  accuracy  :  0.8118125298900047
#  f1-score  :  0.8067763319420576
#  recall    :  0.7794117647058824
#  precision :  0.8361323155216285
#  ========= 2 =========
#  accuracy  :  0.8252032520325203
#  f1-score  :  0.8255786208542113
#  recall    :  0.805025593299209
#  precision :  0.8472086190009794
#  ========= 3 =========
#  accuracy  :  0.8120066969624492
#  f1-score  :  0.812051649928264
#  recall    :  0.7824884792626728
#  precision :  0.8439363817097415
#  ========= 4 =========
#  accuracy  :  0.8060272662042574
#  f1-score  :  0.8075919335705812
#  recall    :  0.7979371776840132
#  precision :  0.8174831892411143
#  ========= 5 =========
#  accuracy  :  0.8065056206649127
#  f1-score  :  0.8033065888645758
#  recall    :  0.786292241789624
#  precision :  0.8210735586481114
#  ======== 최종 ========
#  평균검증 정확도   :  0.812311073150829
#  평균검증 f1-score :  0.8110610250319379
#  평균검증 정밀도   :  0.7902310513482802
#  평균검증 재현율   :  0.833166812824315
#
#
#    ---------- [5-Fold] RandomForest Classifcation Result ----------
#  ========= 1 =========
#  accuracy  :  0.9258727881396461
#  f1-score  :  0.9271958666040394
#  recall    :  0.9364326375711575
#  precision :  0.9181395348837209
#  ========= 2 =========
#  accuracy  :  0.9306551889048302
#  f1-score  :  0.9334251606978881
#  recall    :  0.946021405304793
#  precision :  0.9211599456275487
#  ========= 3 =========
#  accuracy  :  0.9332695527385793
#  f1-score  :  0.9363740022805018
#  recall    :  0.9460829493087558
#  precision :  0.92686230248307
#  ========= 4 =========
#  accuracy  :  0.9263334130590768
#  f1-score  :  0.9291302346985734
#  recall    :  0.9465541490857946
#  precision :  0.912336195210122
#  ========= 5 =========
#  accuracy  :  0.9272901219803875
#  f1-score  :  0.9287388654477263
#  recall    :  0.9428843407901
#  precision :  0.9150115473441108
#  ======== 최종 ========
#  평균검증 정확도   :  0.928684212964504
#  평균검증 f1-score :  0.9309728259457458
#  평균검증 정밀도   :  0.94359509641212
#  평균검증 재현율   :  0.9187019051097145

# %%
# 나온 결과 확인
score_result
# Out:
#    logistic_Acc  logistic_F1  logistic_Rec  logistic_Pre  naivebayes_Acc  \
# 0      0.926321     0.926863      0.921353      0.932439        0.750695
# 1      0.962109     0.962792      0.964352      0.961237        0.784420
# 2      0.974892     0.975427      0.977028      0.973832        0.814204
#
#    naivebayes_F1  naivebayes_Rec  naivebayes_Pre  randomforest_Acc  \
# 0       0.743443        0.712849        0.776781          0.871177
# 1       0.780230        0.752778        0.809761          0.906566
# 2       0.814426        0.799344        0.830088          0.918460
#
#    logistic_F1  ...  logistic_5fold_Rec  logistic_5fold_Pre  \
# 0     0.873521  ...            0.925496            0.927952
# 1     0.909008  ...            0.960268            0.958191
# 2     0.921229  ...            0.975136            0.976023
#
#    naivebayes_5Fold_Acc  naivebayes_5Fold_F1  naivebayes_5Fold_Rec  \
# 0              0.746664             0.739991              0.711701
# 1              0.781424             0.777650              0.752052
# 2              0.812311             0.811061              0.790231
#
#    naivebayes_5Fold_Pre  randomforest_5Fold_Acc  randomforest_5Fold_F1  \
# 0              0.770751                0.870204               0.872723
# 1              0.805129                0.901422               0.904092
# 2              0.833167                0.928684               0.930973
#
#    randomforest_5Fold_Rec  randomforest_5Fold_Pre
# 0                0.878206                0.867333
# 1                0.914333                0.894107
# 2                0.943595                0.918702
#
# [3 rows x 24 columns]

# %% [markdown]
# ### 모델 이용 데이터셋 분류: eng

# %%
# 데이터 로드
eng_ratio5_2gram = np.load('./save_embeddings/eng_ratio5_2gram_embedding.npy', allow_pickle=True)
eng_ratio5_3gram = np.load('./save_embeddings/eng_ratio5_3gram_embedding.npy', allow_pickle=True)
eng_ratio5_4gram = np.load('./save_embeddings/eng_ratio5_4gram_embedding.npy', allow_pickle=True)

eng_ratio10_2gram = np.load('./save_embeddings/eng_ratio10_2gram_embedding.npy', allow_pickle=True)
eng_ratio10_3gram = np.load('./save_embeddings/eng_ratio10_3gram_embedding.npy', allow_pickle=True)
eng_ratio10_4gram = np.load('./save_embeddings/eng_ratio10_4gram_embedding.npy', allow_pickle=True)

# %%
# eng_ratio5_2gram
eng_r5_2g = total_model(eng_ratio5_2gram)
score_result = result_append(score_result, eng_r5_2g)
# Out:
# 304 번 인덱스 오류 처리 완료
# 330 번 인덱스 오류 처리 완료
# 332 번 인덱스 오류 처리 완료
#  데이터 가공 완료
#
#       ----------    Logistic Regression Result    ----------
#  accuracy  :  0.9230769230769231
#  f1-score  :  0.9239230064161321
#  recall    :  0.9218106995884774
#  precision :  0.9260450160771704
#       ---------- Naive Bayes Classification Result ----------
#  accuracy  :  0.7511584800741428
#  f1-score  :  0.7468175388967467
#  recall    :  0.7242798353909465
#  precision :  0.7708029197080292
#       ---------- RandomForest Classifcation Result ----------
#  accuracy  :  0.8635310472659871
#  f1-score  :  0.8658008658008658
#  recall    :  0.8687700045724737
#  precision :  0.8628519527702089
#
#
#    ----------    [5-Fold] Logistic Regression Result    ----------
#  ========= 1 =========
#  accuracy  :  0.9219184430027804
#  f1-score  :  0.9225821272685505
#  recall    :  0.9177330895795247
#  precision :  0.9274826789838337
#  ========= 2 =========
#  accuracy  :  0.9230769230769231
#  f1-score  :  0.9246139872842869
#  recall    :  0.9275626423690205
#  precision :  0.9216840199185151
#  ========= 3 =========
#  accuracy  :  0.9165894346617238
#  f1-score  :  0.9189554254840162
#  recall    :  0.9197836863452006
#  precision :  0.9181286549707602
#  ========= 4 =========
#  accuracy  :  0.9309545875810936
#  f1-score  :  0.9312096029547552
#  recall    :  0.929921622867681
#  precision :  0.9325011558021267
#  ========= 5 =========
#  accuracy  :  0.919601482854495
#  f1-score  :  0.9201380897583429
#  recall    :  0.9241793804900601
#  precision :  0.9161319890009166
#  ======== 최종 ========
#  평균검증 정확도   :  0.9224281742354032
#  평균검증 f1-score :  0.9234998465499903
#  평균검증 정밀도   :  0.9238360843302974
#  평균검증 재현율   :  0.9231856997352305
#
#
#    ---------- [5-Fold] Naive Bayes Classification Result ----------
#  ========= 1 =========
#  accuracy  :  0.7518535681186284
#  f1-score  :  0.7523699421965319
#  recall    :  0.743601462522852
#  precision :  0.7613476836686944
#  ========= 2 =========
#  accuracy  :  0.7657553290083411
#  f1-score  :  0.7641707487753673
#  recall    :  0.7462414578587699
#  precision :  0.7829827915869981
#  ========= 3 =========
#  accuracy  :  0.75
#  f1-score  :  0.7504048114735137
#  recall    :  0.7309598918431726
#  precision :  0.7709125475285171
#  ========= 4 =========
#  accuracy  :  0.7495366079703429
#  f1-score  :  0.7449870252418023
#  recall    :  0.7279852466574458
#  precision :  0.7628019323671498
#  ========= 5 =========
#  accuracy  :  0.7497683039851715
#  f1-score  :  0.7457627118644068
#  recall    :  0.7323162274618585
#  precision :  0.7597122302158273
#  ======== 최종 ========
#  평균검증 정확도   :  0.7533827618164967
#  평균검증 f1-score :  0.7515390479103244
#  평균검증 정밀도   :  0.7362208572688198
#  평균검증 재현율   :  0.7675514370734373
#
#
#    ---------- [5-Fold] RandomForest Classifcation Result ----------
#  ========= 1 =========
#  accuracy  :  0.8649212233549582
#  f1-score  :  0.8673492605233218
#  recall    :  0.8711151736745887
#  precision :  0.8636157680108745
#  ========= 2 =========
#  accuracy  :  0.8730305838739574
#  f1-score  :  0.8755111313039527
#  recall    :  0.8779043280182233
#  precision :  0.87313094698686
#  ========= 3 =========
#  accuracy  :  0.8595922150139017
#  f1-score  :  0.8620218579234974
#  recall    :  0.8530869761153673
#  precision :  0.8711458812701335
#  ========= 4 =========
#  accuracy  :  0.870713623725672
#  f1-score  :  0.8726608854404382
#  recall    :  0.8815122176118027
#  precision :  0.8639855399909625
#  ========= 5 =========
#  accuracy  :  0.8632993512511585
#  f1-score  :  0.8644301470588235
#  recall    :  0.869625520110957
#  precision :  0.8592964824120602
#  ======== 최종 ========
#  평균검증 정확도   :  0.8663113994439297
#  평균검증 f1-score :  0.8683946564500067
#  평균검증 정밀도   :  0.8706488431061878
#  평균검증 재현율   :  0.8662349237341782

# %%
# eng_ratio5_3gram
eng_r5_3g = total_model(eng_ratio5_3gram)
score_result = result_append(score_result, eng_r5_3g)
# Out:
# 264 번 인덱스 오류 처리 완료
# 304 번 인덱스 오류 처리 완료
# 316 번 인덱스 오류 처리 완료
# 330 번 인덱스 오류 처리 완료
# 332 번 인덱스 오류 처리 완료
# 334 번 인덱스 오류 처리 완료
#  데이터 가공 완료
#
#       ----------    Logistic Regression Result    ----------
#  accuracy  :  0.9548128971522711
#  f1-score  :  0.9555966697502313
#  recall    :  0.9564814814814815
#  precision :  0.9547134935304991
#       ---------- Naive Bayes Classification Result ----------
#  accuracy  :  0.7905389503412568
#  f1-score  :  0.7925407925407926
#  recall    :  0.7870370370370371
#  precision :  0.7981220657276995
#       ---------- RandomForest Classifcation Result ----------
#  accuracy  :  0.8985643680866087
#  f1-score  :  0.9009878244888583
#  recall    :  0.9078703703703703
#  precision :  0.8942088463292294
#
#
#    ----------    [5-Fold] Logistic Regression Result    ----------
#  ========= 1 =========
#  accuracy  :  0.9416333254883502
#  f1-score  :  0.9422180801491147
#  recall    :  0.9461862423958821
#  precision :  0.9382830626450116
#  ========= 2 =========
#  accuracy  :  0.9510473052482937
#  f1-score  :  0.9523809523809523
#  recall    :  0.9523809523809523
#  precision :  0.9523809523809523
#  ========= 3 =========
#  accuracy  :  0.9524482109227872
#  f1-score  :  0.9540700318326512
#  recall    :  0.957553628480146
#  precision :  0.9506116900770276
#  ========= 4 =========
#  accuracy  :  0.9562146892655368
#  f1-score  :  0.9566635601118361
#  recall    :  0.9557728119180633
#  precision :  0.9575559701492538
#  ========= 5 =========
#  accuracy  :  0.9585687382297552
#  f1-score  :  0.9586077140169332
#  recall    :  0.954119850187266
#  precision :  0.9631379962192816
#  ======== 최종 ========
#  평균검증 정확도   :  0.9519824538309447
#  평균검증 f1-score :  0.9527880676982974
#  평균검증 정밀도   :  0.9532026970724619
#  평균검증 재현율   :  0.9523939342943054
#
#
#    ---------- [5-Fold] Naive Bayes Classification Result ----------
#  ========= 1 =========
#  accuracy  :  0.785831960461285
#  f1-score  :  0.7842579421526791
#  recall    :  0.7739822180627047
#  precision :  0.7948101874098991
#  ========= 2 =========
#  accuracy  :  0.7832431160273006
#  f1-score  :  0.7869535045107564
#  recall    :  0.7788461538461539
#  precision :  0.7952314165497896
#  ========= 3 =========
#  accuracy  :  0.8001412429378532
#  f1-score  :  0.8021440223724073
#  recall    :  0.7854860794157918
#  precision :  0.8195238095238095
#  ========= 4 =========
#  accuracy  :  0.7961393596986818
#  f1-score  :  0.7957547169811321
#  recall    :  0.7853817504655494
#  precision :  0.8064053537284895
#  ========= 5 =========
#  accuracy  :  0.7937853107344632
#  f1-score  :  0.7911301859799714
#  recall    :  0.776685393258427
#  precision :  0.8061224489795918
#  ======== 최종 ========
#  평균검증 정확도   :  0.7918281979719167
#  평균검증 f1-score :  0.7920480743993893
#  평균검증 정밀도   :  0.7800763190097253
#  평균검증 재현율   :  0.8044186432383158
#
#
#    ---------- [5-Fold] RandomForest Classifcation Result ----------
#  ========= 1 =========
#  accuracy  :  0.8893857378206637
#  f1-score  :  0.891052387575336
#  recall    :  0.8993916705662143
#  precision :  0.8828663298116675
#  ========= 2 =========
#  accuracy  :  0.8959755236526241
#  f1-score  :  0.8982035928143712
#  recall    :  0.8928571428571429
#  precision :  0.9036144578313253
#  ========= 3 =========
#  accuracy  :  0.8975988700564972
#  f1-score  :  0.9013381719210706
#  recall    :  0.9068918302145139
#  precision :  0.8958521190261497
#  ========= 4 =========
#  accuracy  :  0.8973634651600754
#  f1-score  :  0.8996316758747699
#  recall    :  0.909683426443203
#  precision :  0.8897996357012751
#  ========= 5 =========
#  accuracy  :  0.8938323917137476
#  f1-score  :  0.8949941792782306
#  recall    :  0.899812734082397
#  precision :  0.890226956924502
#  ======== 최종 ========
#  평균검증 정확도   :  0.8948311976807215
#  평균검증 f1-score :  0.8970440014927556
#  평균검증 정밀도   :  0.9017273608326942
#  평균검증 재현율   :  0.8924718998589839

# %%
# eng_ratio5_4gram
eng_r5_4g = total_model(eng_ratio5_4gram)
score_result = result_append(score_result, eng_r5_4g)
# Out:
# 264 번 인덱스 오류 처리 완료
# 291 번 인덱스 오류 처리 완료
# 304 번 인덱스 오류 처리 완료
# 316 번 인덱스 오류 처리 완료
# 330 번 인덱스 오류 처리 완료
# 331 번 인덱스 오류 처리 완료
# 332 번 인덱스 오류 처리 완료
# 334 번 인덱스 오류 처리 완료
#  데이터 가공 완료
#
#       ----------    Logistic Regression Result    ----------
#  accuracy  :  0.9720229555236729
#  f1-score  :  0.9726443768996961
#  recall    :  0.9751523675574308
#  precision :  0.9701492537313433
#       ---------- Naive Bayes Classification Result ----------
#  accuracy  :  0.8137254901960784
#  f1-score  :  0.814920408648135
#  recall    :  0.804031879981247
#  precision :  0.8261078998073218
#       ---------- RandomForest Classifcation Result ----------
#  accuracy  :  0.9167862266857962
#  f1-score  :  0.9194817214252661
#  recall    :  0.9315518049695265
#  precision :  0.9077204202832344
#
#
#    ----------    [5-Fold] Logistic Regression Result    ----------
#  ========= 1 =========
#  accuracy  :  0.966284074605452
#  f1-score  :  0.966579758236549
#  recall    :  0.9672675521821632
#  precision :  0.9658929417337755
#  ========= 2 =========
#  accuracy  :  0.9751315160210425
#  f1-score  :  0.9758588672237698
#  recall    :  0.9781293624941834
#  precision :  0.9735988883742474
#  ========= 3 =========
#  accuracy  :  0.9720162640516623
#  f1-score  :  0.9730228268388287
#  recall    :  0.9723502304147466
#  precision :  0.9736963544070143
#  ========= 4 =========
#  accuracy  :  0.9739296818942836
#  f1-score  :  0.9745267585884552
#  recall    :  0.9774964838255977
#  precision :  0.9715750232991612
#  ========= 5 =========
#  accuracy  :  0.9674718966754365
#  f1-score  :  0.9676036207717961
#  recall    :  0.9666825321275583
#  precision :  0.9685264663805436
#  ======== 최종 ========
#  평균검증 정확도   :  0.9709666866495754
#  평균검증 f1-score :  0.9715183663318797
#  평균검증 정밀도   :  0.9723852322088499
#  평균검증 재현율   :  0.9706579348389484
#
#
#    ---------- [5-Fold] Naive Bayes Classification Result ----------
#  ========= 1 =========
#  accuracy  :  0.8118125298900047
#  f1-score  :  0.8118575185273726
#  recall    :  0.8055028462998103
#  precision :  0.8183132530120482
#  ========= 2 =========
#  accuracy  :  0.8134863701578192
#  f1-score  :  0.8159509202453987
#  recall    :  0.8045602605863192
#  precision :  0.8276687410244136
#  ========= 3 =========
#  accuracy  :  0.8043530255919636
#  f1-score  :  0.8066193853427897
#  recall    :  0.7861751152073733
#  precision :  0.8281553398058252
#  ========= 4 =========
#  accuracy  :  0.8100932791198278
#  f1-score  :  0.8137024870952605
#  recall    :  0.8129395218002813
#  precision :  0.814466885861907
#  ========= 5 =========
#  accuracy  :  0.8177469504903133
#  f1-score  :  0.8168269230769231
#  recall    :  0.8086625416468348
#  precision :  0.8251578436134046
#  ======== 최종 ========
#  평균검증 정확도   :  0.8114984310499859
#  평균검증 f1-score :  0.8129914468575489
#  평균검증 정밀도   :  0.8035680571081238
#  평균검증 재현율   :  0.8227524126635197
#
#
#    ---------- [5-Fold] RandomForest Classifcation Result ----------
#  ========= 1 =========
#  accuracy  :  0.9170253467240554
#  f1-score  :  0.9178309258820744
#  recall    :  0.9193548387096774
#  precision :  0.9163120567375886
#  ========= 2 =========
#  accuracy  :  0.9191774270683883
#  f1-score  :  0.9217954650624711
#  recall    :  0.9269427640763146
#  precision :  0.9167050161067648
#  ========= 3 =========
#  accuracy  :  0.9186797416885912
#  f1-score  :  0.9218749999999999
#  recall    :  0.9244239631336405
#  precision :  0.919340054995417
#  ========= 4 =========
#  accuracy  :  0.9174838555369529
#  f1-score  :  0.9203784906531273
#  recall    :  0.9348335677449602
#  precision :  0.9063636363636364
#  ========= 5 =========
#  accuracy  :  0.9160487921549868
#  f1-score  :  0.9169623846699787
#  recall    :  0.9224178962398858
#  precision :  0.9115710253998118
#  ======== 최종 ========
#  평균검증 정확도   :  0.917683032634595
#  평균검증 f1-score :  0.9197684532535304
#  평균검증 정밀도   :  0.9255946059808957
#  평균검증 재현율   :  0.9140583579206437

# %%
# eng_ratio10_2gram
eng_r10_2g = total_model(eng_ratio10_2gram)
score_result = result_append(score_result, eng_r10_2g)
# Out:
# 304 번 인덱스 오류 처리 완료
# 330 번 인덱스 오류 처리 완료
# 332 번 인덱스 오류 처리 완료
#  데이터 가공 완료
#
#       ----------    Logistic Regression Result    ----------
#  accuracy  :  0.9230769230769231
#  f1-score  :  0.9238532110091744
#  recall    :  0.9208962048468221
#  precision :  0.926829268292683
#       ---------- Naive Bayes Classification Result ----------
#  accuracy  :  0.7493049119555144
#  f1-score  :  0.7466042154566745
#  recall    :  0.7288523090992227
#  precision :  0.7652424387902065
#       ---------- RandomForest Classifcation Result ----------
#  accuracy  :  0.8591288229842446
#  f1-score  :  0.8615034168564921
#  recall    :  0.8646547782350251
#  precision :  0.8583749432591921
#
#
#    ----------    [5-Fold] Logistic Regression Result    ----------
#  ========= 1 =========
#  accuracy  :  0.9212233549582948
#  f1-score  :  0.9219108865411115
#  recall    :  0.9172760511882998
#  precision :  0.9265927977839336
#  ========= 2 =========
#  accuracy  :  0.9198331788693235
#  f1-score  :  0.9213636363636364
#  recall    :  0.9234624145785877
#  precision :  0.9192743764172335
#  ========= 3 =========
#  accuracy  :  0.9142724745134384
#  f1-score  :  0.9167791273054431
#  recall    :  0.918431726002704
#  precision :  0.9151324651998204
#  ========= 4 =========
#  accuracy  :  0.9291010194624653
#  f1-score  :  0.9294605809128631
#  recall    :  0.9294605809128631
#  precision :  0.9294605809128631
#  ========= 5 =========
#  accuracy  :  0.9186746987951807
#  f1-score  :  0.9194029850746269
#  recall    :  0.9255663430420712
#  precision :  0.9133211678832117
#  ======== 최종 ========
#  평균검증 정확도   :  0.9206209453197405
#  평균검증 f1-score :  0.9217834432395362
#  평균검증 정밀도   :  0.9228394231449052
#  평균검증 재현율   :  0.9207562776394125
#
#
#    ---------- [5-Fold] Naive Bayes Classification Result ----------
#  ========= 1 =========
#  accuracy  :  0.7511584800741428
#  f1-score  :  0.753216911764706
#  recall    :  0.7490859232175503
#  precision :  0.7573937153419593
#  ========= 2 =========
#  accuracy  :  0.7574142724745134
#  f1-score  :  0.7581427581427582
#  recall    :  0.7476082004555809
#  precision :  0.7689784442361762
#  ========= 3 =========
#  accuracy  :  0.747451343836886
#  f1-score  :  0.7498852684717761
#  recall    :  0.7363677332131591
#  precision :  0.7639083683964469
#  ========= 4 =========
#  accuracy  :  0.7446709916589435
#  f1-score  :  0.7414359455654622
#  recall    :  0.7284462886122637
#  precision :  0.754897276636407
#  ========= 5 =========
#  accuracy  :  0.7506950880444856
#  f1-score  :  0.749534450651769
#  recall    :  0.7443365695792881
#  precision :  0.7548054383497421
#  ======== 최종 ========
#  평균검증 정확도   :  0.7502780352177943
#  평균검증 f1-score :  0.7504430669192944
#  평균검증 정밀도   :  0.7411689430155685
#  평균검증 재현율   :  0.7599966485921462
#
#
#    ---------- [5-Fold] RandomForest Classifcation Result ----------
#  ========= 1 =========
#  accuracy  :  0.8639944392956441
#  f1-score  :  0.8671043694815486
#  recall    :  0.8752285191956124
#  precision :  0.8591296545536115
#  ========= 2 =========
#  accuracy  :  0.8716404077849861
#  f1-score  :  0.8747173224785165
#  recall    :  0.8810933940774488
#  precision :  0.8684328693309384
#  ========= 3 =========
#  accuracy  :  0.8561167747914736
#  f1-score  :  0.8595340420719294
#  recall    :  0.8562415502478594
#  precision :  0.8628519527702089
#  ========= 4 =========
#  accuracy  :  0.8651529193697869
#  f1-score  :  0.8666972056802564
#  recall    :  0.8722913785154449
#  precision :  0.8611743286299499
#  ========= 5 =========
#  accuracy  :  0.8619091751621872
#  f1-score  :  0.8635531135531135
#  recall    :  0.8719371243643088
#  precision :  0.8553287981859411
#  ======== 최종 ========
#  평균검증 정확도   :  0.8637627432808156
#  평균검증 f1-score :  0.8663212106530729
#  평균검증 정밀도   :  0.8713583932801349
#  평균검증 재현율   :  0.8613835206941299

# %%
# eng_ratio10_3gram
eng_r10_3g = total_model(eng_ratio10_3gram)
score_result = result_append(score_result, eng_r10_3g)
# Out:
# 264 번 인덱스 오류 처리 완료
# 304 번 인덱스 오류 처리 완료
# 316 번 인덱스 오류 처리 완료
# 330 번 인덱스 오류 처리 완료
# 332 번 인덱스 오류 처리 완료
# 334 번 인덱스 오류 처리 완료
#  데이터 가공 완료
#
#       ----------    Logistic Regression Result    ----------
#  accuracy  :  0.953165450694281
#  f1-score  :  0.9539031735001158
#  recall    :  0.9532407407407407
#  precision :  0.9545665275846082
#       ---------- Naive Bayes Classification Result ----------
#  accuracy  :  0.7841845140032949
#  f1-score  :  0.7877806063411248
#  recall    :  0.787962962962963
#  precision :  0.7875983341045812
#       ---------- RandomForest Classifcation Result ----------
#  accuracy  :  0.8938573782066369
#  f1-score  :  0.8966307586523035
#  recall    :  0.9055555555555556
#  precision :  0.887880163413527
#
#
#    ----------    [5-Fold] Logistic Regression Result    ----------
#  ========= 1 =========
#  accuracy  :  0.9456342668863262
#  f1-score  :  0.9459901800327332
#  recall    :  0.9466541881141788
#  precision :  0.9453271028037383
#  ========= 2 =========
#  accuracy  :  0.9510473052482937
#  f1-score  :  0.9524680073126143
#  recall    :  0.9542124542124543
#  precision :  0.9507299270072993
#  ========= 3 =========
#  accuracy  :  0.9524482109227872
#  f1-score  :  0.9539023277042448
#  recall    :  0.9539023277042447
#  precision :  0.9539023277042447
#  ========= 4 =========
#  accuracy  :  0.9559792843691148
#  f1-score  :  0.9563593932322054
#  recall    :  0.9539106145251397
#  precision :  0.9588207767898924
#  ========= 5 =========
#  accuracy  :  0.9583333333333334
#  f1-score  :  0.9584994138335287
#  recall    :  0.9569288389513109
#  precision :  0.960075152653828
#  ======== 최종 ========
#  평균검증 정확도   :  0.952688480151971
#  평균검증 f1-score :  0.9534438644230653
#  평균검증 정밀도   :  0.9531216847014656
#  평균검증 재현율   :  0.9537710573918006
#
#
#    ---------- [5-Fold] Naive Bayes Classification Result ----------
#  ========= 1 =========
#  accuracy  :  0.7832431160273006
#  f1-score  :  0.7836504580690627
#  recall    :  0.7805334581188582
#  precision :  0.7867924528301887
#  ========= 2 =========
#  accuracy  :  0.7766533301953401
#  f1-score  :  0.7809831525501962
#  recall    :  0.7747252747252747
#  precision :  0.7873429502093997
#  ========= 3 =========
#  accuracy  :  0.7996704331450094
#  f1-score  :  0.8030548484147189
#  recall    :  0.7918758557736193
#  precision :  0.8145539906103286
#  ========= 4 =========
#  accuracy  :  0.7930790960451978
#  f1-score  :  0.7933223606865741
#  recall    :  0.7853817504655494
#  precision :  0.8014251781472684
#  ========= 5 =========
#  accuracy  :  0.7848399246704332
#  f1-score  :  0.7850423330197555
#  recall    :  0.7813670411985019
#  precision :  0.7887523629489603
#  ======== 최종 ========
#  평균검증 정확도   :  0.7874971800166563
#  평균검증 f1-score :  0.7892106305480615
#  평균검증 정밀도   :  0.7827766760563607
#  평균검증 재현율   :  0.7957733869492292
#
#
#    ---------- [5-Fold] RandomForest Classifcation Result ----------
#  ========= 1 =========
#  accuracy  :  0.8832666509767004
#  f1-score  :  0.8849721706864563
#  recall    :  0.8928404305100608
#  precision :  0.8772413793103448
#  ========= 2 =========
#  accuracy  :  0.8898564368086609
#  f1-score  :  0.8928080622995878
#  recall    :  0.8923992673992674
#  precision :  0.8932172318973419
#  ========= 3 =========
#  accuracy  :  0.8990112994350282
#  f1-score  :  0.9026990247221591
#  recall    :  0.9082610680054769
#  precision :  0.8972046889089269
#  ========= 4 =========
#  accuracy  :  0.8987758945386064
#  f1-score  :  0.900555041628122
#  recall    :  0.9064245810055865
#  precision :  0.8947610294117647
#  ========= 5 =========
#  accuracy  :  0.8907721280602636
#  f1-score  :  0.8921933085501859
#  recall    :  0.898876404494382
#  precision :  0.8856088560885609
#  ======== 최종 ========
#  평균검증 정확도   :  0.8923364819638518
#  평균검증 f1-score :  0.8946455215773023
#  평균검증 정밀도   :  0.8997603502829549
#  평균검증 재현율   :  0.8896066371233878

# %%
# eng_ratio10_4gram
eng_r10_4g = total_model(eng_ratio10_4gram)
score_result = result_append(score_result, eng_r10_4g)
# Out:
# 264 번 인덱스 오류 처리 완료
# 291 번 인덱스 오류 처리 완료
# 304 번 인덱스 오류 처리 완료
# 316 번 인덱스 오류 처리 완료
# 330 번 인덱스 오류 처리 완료
# 331 번 인덱스 오류 처리 완료
# 332 번 인덱스 오류 처리 완료
# 334 번 인덱스 오류 처리 완료
#  데이터 가공 완료
#
#       ----------    Logistic Regression Result    ----------
#  accuracy  :  0.9681970349115255
#  f1-score  :  0.9689034369885433
#  recall    :  0.9714017815283638
#  precision :  0.9664179104477612
#       ---------- Naive Bayes Classification Result ----------
#  accuracy  :  0.810856049736968
#  f1-score  :  0.8137508829762186
#  recall    :  0.810126582278481
#  precision :  0.8174077578051088
#       ---------- RandomForest Classifcation Result ----------
#  accuracy  :  0.912960306073649
#  f1-score  :  0.9156626506024096
#  recall    :  0.9263947491795593
#  precision :  0.9051763628034815
#
#
#    ----------    [5-Fold] Logistic Regression Result    ----------
#  ========= 1 =========
#  accuracy  :  0.9672405547584888
#  f1-score  :  0.9675124496087266
#  recall    :  0.967741935483871
#  precision :  0.9672830725462305
#  ========= 2 =========
#  accuracy  :  0.9734576757532282
#  f1-score  :  0.9742040436904486
#  recall    :  0.9753373662168451
#  precision :  0.9730733519034355
#  ========= 3 =========
#  accuracy  :  0.9701028462090409
#  f1-score  :  0.9710312862108923
#  recall    :  0.9654377880184332
#  precision :  0.9766899766899767
#  ========= 4 =========
#  accuracy  :  0.9705812006696962
#  f1-score  :  0.971201123858581
#  recall    :  0.9723394280356306
#  precision :  0.9700654817586529
#  ========= 5 =========
#  accuracy  :  0.9660368332934705
#  f1-score  :  0.9661582459485223
#  recall    :  0.9647786768205616
#  precision :  0.9675417661097852
#  ======== 최종 ========
#  평균검증 정확도   :  0.969483822136785
#  평균검증 f1-score :  0.9700214298634341
#  평균검증 정밀도   :  0.9691270389150682
#  평균검증 재현율   :  0.9709307298016162
#
#
#    ---------- [5-Fold] Naive Bayes Classification Result ----------
#  ========= 1 =========
#  accuracy  :  0.8091822094691535
#  f1-score  :  0.8096374045801527
#  recall    :  0.8050284629981025
#  precision :  0.814299424184261
#  ========= 2 =========
#  accuracy  :  0.8113342898134863
#  f1-score  :  0.8149190710767066
#  recall    :  0.808282922289437
#  precision :  0.8216650898770104
#  ========= 3 =========
#  accuracy  :  0.8079406840468787
#  f1-score  :  0.8121637426900585
#  recall    :  0.8
#  precision :  0.8247030878859858
#  ========= 4 =========
#  accuracy  :  0.801961253288687
#  f1-score  :  0.8066324147594582
#  recall    :  0.8096577590248476
#  precision :  0.8036295951605398
#  ========= 5 =========
#  accuracy  :  0.8072231523558957
#  f1-score  :  0.80726924916308
#  recall    :  0.803426939552594
#  precision :  0.8111484863046612
#  ======== 최종 ========
#  평균검증 정확도   :  0.8075283177948203
#  평균검증 f1-score :  0.8101243764538912
#  평균검증 정밀도   :  0.8052792167729963
#  평균검증 재현율   :  0.8150891366824917
#
#
#    ---------- [5-Fold] RandomForest Classifcation Result ----------
#  ========= 1 =========
#  accuracy  :  0.9184600669536107
#  f1-score  :  0.9194805194805195
#  recall    :  0.9236242884250474
#  precision :  0.9153737658674189
#  ========= 2 =========
#  accuracy  :  0.9184600669536107
#  f1-score  :  0.921265296698222
#  recall    :  0.9283387622149837
#  precision :  0.9142988084326306
#  ========= 3 =========
#  accuracy  :  0.9177230327672805
#  f1-score  :  0.9212093449381585
#  recall    :  0.9267281105990783
#  precision :  0.9157559198542805
#  ========= 4 =========
#  accuracy  :  0.9117436020090888
#  f1-score  :  0.9147215160619367
#  recall    :  0.9278012189404594
#  precision :  0.9020054694621695
#  ========= 5 =========
#  accuracy  :  0.9129394881607271
#  f1-score  :  0.9139072847682119
#  recall    :  0.9195621132793907
#  precision :  0.9083215796897038
#  ======== 최종 ========
#  평균검증 정확도   :  0.9158652513688637
#  평균검증 f1-score :  0.9181167923894098
#  평균검증 정밀도   :  0.9252108986917917
#  평균검증 재현율   :  0.9111511086612406

# %%
# 나온 결과 확인
score_result
# Out:
#    logistic_Acc  logistic_F1  logistic_Rec  logistic_Pre  naivebayes_Acc  \
# 0      0.926321     0.926863      0.921353      0.932439        0.750695
# 1      0.962109     0.962792      0.964352      0.961237        0.784420
# 2      0.974892     0.975427      0.977028      0.973832        0.814204
# 3      0.923077     0.923923      0.921811      0.926045        0.751158
# 4      0.954813     0.955597      0.956481      0.954713        0.790539
# 5      0.972023     0.972644      0.975152      0.970149        0.813725
# 6      0.923077     0.923853      0.920896      0.926829        0.749305
# 7      0.953165     0.953903      0.953241      0.954567        0.784185
# 8      0.968197     0.968903      0.971402      0.966418        0.810856
#
#    naivebayes_F1  naivebayes_Rec  naivebayes_Pre  randomforest_Acc  \
# 0       0.743443        0.712849        0.776781          0.871177
# 1       0.780230        0.752778        0.809761          0.906566
# 2       0.814426        0.799344        0.830088          0.918460
# 3       0.746818        0.724280        0.770803          0.863531
# 4       0.792541        0.787037        0.798122          0.898564
# 5       0.814920        0.804032        0.826108          0.916786
# 6       0.746604        0.728852        0.765242          0.859129
# 7       0.787781        0.787963        0.787598          0.893857
# 8       0.813751        0.810127        0.817408          0.912960
#
#    logistic_F1  ...  logistic_5fold_Rec  logistic_5fold_Pre  \
# 0     0.873521  ...            0.925496            0.927952
# 1     0.909008  ...            0.960268            0.958191
# 2     0.921229  ...            0.975136            0.976023
# 3     0.865801  ...            0.923836            0.923186
# 4     0.900988  ...            0.953203            0.952394
# 5     0.919482  ...            0.972385            0.970658
# 6     0.861503  ...            0.922839            0.920756
# 7     0.896631  ...            0.953122            0.953771
# 8     0.915663  ...            0.969127            0.970931
#
#    naivebayes_5Fold_Acc  naivebayes_5Fold_F1  naivebayes_5Fold_Rec  \
# 0              0.746664             0.739991              0.711701
# 1              0.781424             0.777650              0.752052
# 2              0.812311             0.811061              0.790231
# 3              0.753383             0.751539              0.736221
# 4              0.791828             0.792048              0.780076
# 5              0.811498             0.812991              0.803568
# 6              0.750278             0.750443              0.741169
# 7              0.787497             0.789211              0.782777
# 8              0.807528             0.810124              0.805279
#
#    naivebayes_5Fold_Pre  randomforest_5Fold_Acc  randomforest_5Fold_F1  \
# 0              0.770751                0.870204               0.872723
# 1              0.805129                0.901422               0.904092
# 2              0.833167                0.928684               0.930973
# 3              0.767551                0.866311               0.868395
# 4              0.804419                0.894831               0.897044
# 5              0.822752                0.917683               0.919768
# 6              0.759997                0.863763               0.866321
# 7              0.795773                0.892336               0.894646
# 8              0.815089                0.915865               0.918117
#
#    randomforest_5Fold_Rec  randomforest_5Fold_Pre
# 0                0.878206                0.867333
# 1                0.914333                0.894107
# 2                0.943595                0.918702
# 3                0.870649                0.866235
# 4                0.901727                0.892472
# 5                0.925595                0.914058
# 6                0.871358                0.861384
# 7                0.899760                0.889607
# 8                0.925211                0.911151
#
# [9 rows x 24 columns]

# %% [markdown]
# ### 모델 이용 데이터셋 분류: kor

# %%
# 데이터 로드
kor_ratio5_2gram = np.load('./save_embeddings/kor_ratio5_2gram_embedding.npy', allow_pickle=True)
kor_ratio5_3gram = np.load('./save_embeddings/kor_ratio5_3gram_embedding.npy', allow_pickle=True)
kor_ratio5_4gram = np.load('./save_embeddings/kor_ratio5_4gram_embedding.npy', allow_pickle=True)

kor_ratio10_2gram = np.load('./save_embeddings/kor_ratio10_2gram_embedding.npy', allow_pickle=True)
kor_ratio10_3gram = np.load('./save_embeddings/kor_ratio10_3gram_embedding.npy', allow_pickle=True)
kor_ratio10_4gram = np.load('./save_embeddings/kor_ratio10_4gram_embedding.npy', allow_pickle=True)

# %%
# kor_ratio5_2gram
kor_r5_2g = total_model(kor_ratio5_2gram)
score_result = result_append(score_result, kor_r5_2g)
# Out:
# 304 번 인덱스 오류 처리 완료
# 330 번 인덱스 오류 처리 완료
# 332 번 인덱스 오류 처리 완료
#  데이터 가공 완료
#
#       ----------    Logistic Regression Result    ----------
#  accuracy  :  0.9246987951807228
#  f1-score  :  0.9256122682536049
#  recall    :  0.9245541838134431
#  precision :  0.9266727772685609
#       ---------- Naive Bayes Classification Result ----------
#  accuracy  :  0.7613531047265987
#  f1-score  :  0.7546450690805145
#  recall    :  0.7242798353909465
#  precision :  0.7876678269517653
#       ---------- RandomForest Classifcation Result ----------
#  accuracy  :  0.8679332715477294
#  f1-score  :  0.8702185792349727
#  recall    :  0.8737997256515775
#  precision :  0.8666666666666667
#
#
#    ----------    [5-Fold] Logistic Regression Result    ----------
#  ========= 1 =========
#  accuracy  :  0.9223818350324374
#  f1-score  :  0.9230769230769231
#  recall    :  0.9186471663619744
#  precision :  0.9275496077526535
#  ========= 2 =========
#  accuracy  :  0.9253938832252085
#  f1-score  :  0.9264840182648403
#  recall    :  0.924373576309795
#  precision :  0.928604118993135
#  ========= 3 =========
#  accuracy  :  0.9151992585727525
#  f1-score  :  0.9173068233167645
#  recall    :  0.9148264984227129
#  precision :  0.919800634345265
#  ========= 4 =========
#  accuracy  :  0.9346617238183503
#  f1-score  :  0.9348729792147806
#  recall    :  0.9331489165514062
#  precision :  0.9366034243405831
#  ========= 5 =========
#  accuracy  :  0.9230769230769231
#  f1-score  :  0.923572744014733
#  recall    :  0.9274156264447526
#  precision :  0.9197615772581385
#  ======== 최종 ========
#  평균검증 정확도   :  0.9241427247451345
#  평균검증 f1-score :  0.9250626975776083
#  평균검증 정밀도   :  0.9236823568181283
#  평균검증 재현율   :  0.926463872537955
#
#
#    ---------- [5-Fold] Naive Bayes Classification Result ----------
#  ========= 1 =========
#  accuracy  :  0.7650602409638554
#  f1-score  :  0.7621951219512195
#  recall    :  0.7426873857404022
#  precision :  0.7827552986512524
#  ========= 2 =========
#  accuracy  :  0.773401297497683
#  f1-score  :  0.7692307692307693
#  recall    :  0.7425968109339408
#  precision :  0.797846304454234
#  ========= 3 =========
#  accuracy  :  0.7583410565338277
#  f1-score  :  0.7560233918128655
#  recall    :  0.7282559711581793
#  precision :  0.7859922178988327
#  ========= 4 =========
#  accuracy  :  0.7574142724745134
#  f1-score  :  0.749101365923796
#  recall    :  0.7206085753803596
#  precision :  0.7799401197604791
#  ========= 5 =========
#  accuracy  :  0.76274328081557
#  f1-score  :  0.757919621749409
#  recall    :  0.7411003236245954
#  precision :  0.7755200774068699
#  ======== 최종 ========
#  평균검증 정확도   :  0.7633920296570899
#  평균검증 f1-score :  0.7588940541336119
#  평균검증 정밀도   :  0.7350498133674954
#  평균검증 재현율   :  0.7844108036343337
#
#
#    ---------- [5-Fold] RandomForest Classifcation Result ----------
#  ========= 1 =========
#  accuracy  :  0.8663113994439295
#  f1-score  :  0.8689529866000454
#  recall    :  0.8743144424131627
#  precision :  0.8636568848758465
#  ========= 2 =========
#  accuracy  :  0.8755792400370713
#  f1-score  :  0.8784242698664251
#  recall    :  0.8838268792710706
#  precision :  0.873087308730873
#  ========= 3 =========
#  accuracy  :  0.8577386468952733
#  f1-score  :  0.8612742882964302
#  recall    :  0.8589454709328527
#  precision :  0.8636157680108745
#  ========= 4 =========
#  accuracy  :  0.8721037998146431
#  f1-score  :  0.8736842105263157
#  recall    :  0.880129091747349
#  precision :  0.8673330304407088
#  ========= 5 =========
#  accuracy  :  0.8670064874884152
#  f1-score  :  0.8691886964448496
#  recall    :  0.8816458622283865
#  precision :  0.8570786516853932
#  ======== 최종 ========
#  평균검증 정확도   :  0.8677479147358664
#  평균검증 f1-score :  0.8703048903468134
#  평균검증 정밀도   :  0.8757723493185642
#  평균검증 재현율   :  0.8649543287487391

# %%
# kor_ratio5_3gram
kor_r5_3g = total_model(kor_ratio5_3gram)
score_result = result_append(score_result, kor_r5_3g)
# Out:
# 264 번 인덱스 오류 처리 완료
# 304 번 인덱스 오류 처리 완료
# 316 번 인덱스 오류 처리 완료
# 330 번 인덱스 오류 처리 완료
# 332 번 인덱스 오류 처리 완료
# 334 번 인덱스 오류 처리 완료
#  데이터 가공 완료
#
#       ----------    Logistic Regression Result    ----------
#  accuracy  :  0.9564603436102612
#  f1-score  :  0.9572056442285449
#  recall    :  0.9578703703703704
#  precision :  0.9565418400369856
#       ---------- Naive Bayes Classification Result ----------
#  accuracy  :  0.7971287361732172
#  f1-score  :  0.7971764705882353
#  recall    :  0.7842592592592592
#  precision :  0.8105263157894737
#       ---------- RandomForest Classifcation Result ----------
#  accuracy  :  0.9006825135325959
#  f1-score  :  0.9030330882352942
#  recall    :  0.9097222222222222
#  precision :  0.896441605839416
#
#
#    ----------    [5-Fold] Logistic Regression Result    ----------
#  ========= 1 =========
#  accuracy  :  0.9489291598023064
#  f1-score  :  0.9493582263710618
#  recall    :  0.9518015910154423
#  precision :  0.946927374301676
#  ========= 2 =========
#  accuracy  :  0.9536361496822782
#  f1-score  :  0.9548475819390327
#  recall    :  0.9537545787545788
#  precision :  0.9559430931620009
#  ========= 3 =========
#  accuracy  :  0.9566854990583804
#  f1-score  :  0.958048335613315
#  recall    :  0.9589228662711091
#  precision :  0.9571753986332574
#  ========= 4 =========
#  accuracy  :  0.9583333333333334
#  f1-score  :  0.9587508739221627
#  recall    :  0.957635009310987
#  precision :  0.9598693420438638
#  ========= 5 =========
#  accuracy  :  0.9550376647834274
#  f1-score  :  0.9550482466462697
#  recall    :  0.9499063670411985
#  precision :  0.9602460955986749
#  ======== 최종 ========
#  평균검증 정확도   :  0.9545243613319453
#  평균검증 f1-score :  0.9552106528983686
#  평균검증 정밀도   :  0.954404082478663
#  평균검증 재현율   :  0.9560322607478945
#
#
#    ---------- [5-Fold] Naive Bayes Classification Result ----------
#  ========= 1 =========
#  accuracy  :  0.7926570957872441
#  f1-score  :  0.7888809010304337
#  recall    :  0.7702386523163313
#  precision :  0.8084479371316307
#  ========= 2 =========
#  accuracy  :  0.7912449988232525
#  f1-score  :  0.7926116436754735
#  recall    :  0.7760989010989011
#  precision :  0.809842331581462
#  ========= 3 =========
#  accuracy  :  0.8001412429378532
#  f1-score  :  0.7997169143665959
#  recall    :  0.7736193518941122
#  precision :  0.82763671875
#  ========= 4 =========
#  accuracy  :  0.7966101694915254
#  f1-score  :  0.7947743467933491
#  recall    :  0.7788640595903166
#  precision :  0.8113482056256062
#  ========= 5 =========
#  accuracy  :  0.7970809792843692
#  f1-score  :  0.7933844678811122
#  recall    :  0.774812734082397
#  precision :  0.81286836935167
#  ======== 최종 ========
#  평균검증 정확도   :  0.7955468972648487
#  평균검증 f1-score :  0.7938736547493929
#  평균검증 정밀도   :  0.7747267397964117
#  평균검증 재현율   :  0.8140287124880737
#
#
#    ---------- [5-Fold] RandomForest Classifcation Result ----------
#  ========= 1 =========
#  accuracy  :  0.8931513297246411
#  f1-score  :  0.8947124304267162
#  recall    :  0.9026672905942911
#  precision :  0.886896551724138
#  ========= 2 =========
#  accuracy  :  0.8973876206166157
#  f1-score  :  0.9007737824305871
#  recall    :  0.9061355311355311
#  precision :  0.895475113122172
#  ========= 3 =========
#  accuracy  :  0.9018361581920904
#  f1-score  :  0.9052918464683171
#  recall    :  0.90963030579644
#  precision :  0.900994575045208
#  ========= 4 =========
#  accuracy  :  0.9058380414312618
#  f1-score  :  0.9076638965835642
#  recall    :  0.9152700186219739
#  precision :  0.9001831501831502
#  ========= 5 =========
#  accuracy  :  0.8952448210922788
#  f1-score  :  0.8972048972048972
#  recall    :  0.9091760299625468
#  precision :  0.8855449156406748
#  ======== 최종 ========
#  평균검증 정확도   :  0.8986915942113776
#  평균검증 f1-score :  0.9011293706228164
#  평균검증 정밀도   :  0.9085758352221566
#  평균검증 재현율   :  0.8938188611430686

# %%
# kor_ratio5_4gram
kor_r5_4g = total_model(kor_ratio5_4gram)
score_result = result_append(score_result, kor_r5_4g)
# Out:
# 264 번 인덱스 오류 처리 완료
# 291 번 인덱스 오류 처리 완료
# 304 번 인덱스 오류 처리 완료
# 316 번 인덱스 오류 처리 완료
# 330 번 인덱스 오류 처리 완료
# 331 번 인덱스 오류 처리 완료
# 332 번 인덱스 오류 처리 완료
# 334 번 인덱스 오류 처리 완료
#  데이터 가공 완료
#
#       ----------    Logistic Regression Result    ----------
#  accuracy  :  0.9717838354854137
#  f1-score  :  0.9723134678554668
#  recall    :  0.9714017815283638
#  precision :  0.9732268670737435
#       ---------- Naive Bayes Classification Result ----------
#  accuracy  :  0.8311812529890005
#  f1-score  :  0.8319047619047619
#  recall    :  0.8190342240975153
#  precision :  0.8451862602806
#       ---------- RandomForest Classifcation Result ----------
#  accuracy  :  0.9230033476805356
#  f1-score  :  0.9251858736059481
#  recall    :  0.93342709798406
#  precision :  0.9170888991248273
#
#
#    ----------    [5-Fold] Logistic Regression Result    ----------
#  ========= 1 =========
#  accuracy  :  0.9708273553323769
#  f1-score  :  0.9710351377018044
#  recall    :  0.9701138519924098
#  precision :  0.971958174904943
#  ========= 2 =========
#  accuracy  :  0.9780009564801531
#  f1-score  :  0.9785847299813781
#  recall    :  0.9781293624941834
#  precision :  0.9790405216581276
#  ========= 3 =========
#  accuracy  :  0.9746472135852667
#  f1-score  :  0.9754515979620194
#  recall    :  0.9705069124423963
#  precision :  0.9804469273743017
#  ========= 4 =========
#  accuracy  :  0.9732121502033007
#  f1-score  :  0.9738684087727486
#  recall    :  0.9784341303328645
#  precision :  0.9693450998606595
#  ========= 5 =========
#  accuracy  :  0.9672327194451088
#  f1-score  :  0.9673731840914503
#  recall    :  0.9666825321275583
#  precision :  0.9680648236415634
#  ======== 최종 ========
#  평균검증 정확도   :  0.9727840790092411
#  평균검증 f1-score :  0.9732626117018801
#  평균검증 정밀도   :  0.9727733578778824
#  평균검증 재현율   :  0.973771109487919
#
#
#    ---------- [5-Fold] Naive Bayes Classification Result ----------
#  ========= 1 =========
#  accuracy  :  0.8170731707317073
#  f1-score  :  0.8147251150399611
#  recall    :  0.7979127134724858
#  precision :  0.8322612568035626
#  ========= 2 =========
#  accuracy  :  0.8318986131037781
#  f1-score  :  0.8334517886756693
#  recall    :  0.8185202419730107
#  precision :  0.8489382239382239
#  ========= 3 =========
#  accuracy  :  0.8237263812485052
#  f1-score  :  0.8241469816272966
#  recall    :  0.7958525345622119
#  precision :  0.8545274616526473
#  ========= 4 =========
#  accuracy  :  0.8227696723271944
#  f1-score  :  0.8246983676366217
#  recall    :  0.8171589310829818
#  precision :  0.832378223495702
#  ========= 5 =========
#  accuracy  :  0.8249222674001435
#  f1-score  :  0.8231884057971015
#  recall    :  0.8110423607805807
#  precision :  0.8357037763609613
#  ======== 최종 ========
#  평균검증 정확도   :  0.8240780209622656
#  평균검증 f1-score :  0.82404213175533
#  평균검증 정밀도   :  0.8080973563742543
#  평균검증 재현율   :  0.8407617884502194
#
#
#    ---------- [5-Fold] RandomForest Classifcation Result ----------
#  ========= 1 =========
#  accuracy  :  0.9186991869918699
#  f1-score  :  0.9198113207547169
#  recall    :  0.9250474383301708
#  precision :  0.9146341463414634
#  ========= 2 =========
#  accuracy  :  0.9230033476805356
#  f1-score  :  0.92577224527432
#  recall    :  0.93438808748255
#  precision :  0.9173138419369575
#  ========= 3 =========
#  accuracy  :  0.9301602487443196
#  f1-score  :  0.9328735632183908
#  recall    :  0.9350230414746544
#  precision :  0.9307339449541284
#  ========= 4 =========
#  accuracy  :  0.9222674001435064
#  f1-score  :  0.9249595936273379
#  recall    :  0.9390529770276606
#  precision :  0.9112829845313922
#  ========= 5 =========
#  accuracy  :  0.9182013872279359
#  f1-score  :  0.9195294117647058
#  recall    :  0.9300333174678724
#  precision :  0.9092601209865053
#  ======== 최종 ========
#  평균검증 정확도   :  0.9224663141576336
#  평균검증 f1-score :  0.9245892269278944
#  평균검증 정밀도   :  0.9327089723565816
#  평균검증 재현율   :  0.9166450077500894

# %%
# kor_ratio10_2gram
kor_r10_2g = total_model(kor_ratio10_2gram)
score_result = result_append(score_result, kor_r10_2g)
# Out:
# 304 번 인덱스 오류 처리 완료
# 330 번 인덱스 오류 처리 완료
# 332 번 인덱스 오류 처리 완료
#  데이터 가공 완료
#
#       ----------    Logistic Regression Result    ----------
#  accuracy  :  0.9230769230769231
#  f1-score  :  0.9237482774460266
#  recall    :  0.9195244627343393
#  precision :  0.928011075219197
#       ---------- Naive Bayes Classification Result ----------
#  accuracy  :  0.7634383688600556
#  f1-score  :  0.7569626279457272
#  recall    :  0.7270233196159122
#  precision :  0.7894736842105263
#       ---------- RandomForest Classifcation Result ----------
#  accuracy  :  0.8642261353104727
#  f1-score  :  0.8662711090826107
#  recall    :  0.8678555098308185
#  precision :  0.8646924829157175
#
#
#    ----------    [5-Fold] Logistic Regression Result    ----------
#  ========= 1 =========
#  accuracy  :  0.9214550509731233
#  f1-score  :  0.9223367697594502
#  recall    :  0.920018281535649
#  precision :  0.9246669728984842
#  ========= 2 =========
#  accuracy  :  0.9240037071362373
#  f1-score  :  0.9252165982672138
#  recall    :  0.924373576309795
#  precision :  0.9260611592879964
#  ========= 3 =========
#  accuracy  :  0.9096385542168675
#  f1-score  :  0.9118444846292948
#  recall    :  0.9089680036052276
#  precision :  0.9147392290249433
#  ========= 4 =========
#  accuracy  :  0.9323447636700649
#  f1-score  :  0.9324386857936141
#  recall    :  0.9289995389580452
#  precision :  0.9359033906177426
#  ========= 5 =========
#  accuracy  :  0.9230769230769231
#  f1-score  :  0.9235023041474654
#  recall    :  0.926490984743412
#  precision :  0.9205328433624254
#  ======== 최종 ========
#  평균검증 정확도   :  0.9221037998146432
#  평균검증 f1-score :  0.9230677685194077
#  평균검증 정밀도   :  0.9217700770304258
#  평균검증 재현율   :  0.9243807190383183
#
#
#    ---------- [5-Fold] Naive Bayes Classification Result ----------
#  ========= 1 =========
#  accuracy  :  0.7669138090824837
#  f1-score  :  0.7642924086223055
#  recall    :  0.7454296160877514
#  precision :  0.7841346153846154
#  ========= 2 =========
#  accuracy  :  0.7710843373493976
#  f1-score  :  0.7679661813057774
#  recall    :  0.744874715261959
#  precision :  0.7925351429956374
#  ========= 3 =========
#  accuracy  :  0.755097312326228
#  f1-score  :  0.7530950712450362
#  recall    :  0.7264533573681838
#  precision :  0.7817652764306499
#  ========= 4 =========
#  accuracy  :  0.7564874884151993
#  f1-score  :  0.7480220570606569
#  recall    :  0.719225449515906
#  precision :  0.7792207792207793
#  ========= 5 =========
#  accuracy  :  0.7641334569045413
#  f1-score  :  0.7599056603773584
#  recall    :  0.7447988904299584
#  precision :  0.7756379393355801
#  ======== 최종 ========
#  평균검증 정확도   :  0.76274328081557
#  평균검증 f1-score :  0.7586562757222268
#  평균검증 정밀도   :  0.7361564057327518
#  평균검증 재현율   :  0.7826587506734524
#
#
#    ---------- [5-Fold] RandomForest Classifcation Result ----------
#  ========= 1 =========
#  accuracy  :  0.8614457831325302
#  f1-score  :  0.8652546191978369
#  recall    :  0.8775137111517367
#  precision :  0.8533333333333334
#  ========= 2 =========
#  accuracy  :  0.8739573679332715
#  f1-score  :  0.8766439909297052
#  recall    :  0.8806378132118451
#  precision :  0.872686230248307
#  ========= 3 =========
#  accuracy  :  0.8551899907321594
#  f1-score  :  0.8589483186639586
#  recall    :  0.857593510590356
#  precision :  0.8603074141048824
#  ========= 4 =========
#  accuracy  :  0.8697868396663577
#  f1-score  :  0.8718065693430658
#  recall    :  0.8810511756569848
#  precision :  0.8627539503386005
#  ========= 5 =========
#  accuracy  :  0.8635310472659871
#  f1-score  :  0.8660450307027519
#  recall    :  0.8802588996763754
#  precision :  0.8522829006266786
#  ======== 최종 ========
#  평균검증 정확도   :  0.8647822057460612
#  평균검증 f1-score :  0.8677397057674637
#  평균검증 정밀도   :  0.8754110220574596
#  평균검증 재현율   :  0.8602727657303604

# %%
# kor_ratio10_3gram
kor_r10_3g = total_model(kor_ratio10_3gram)
score_result = result_append(score_result, kor_r10_3g)
# Out:
# 264 번 인덱스 오류 처리 완료
# 304 번 인덱스 오류 처리 완료
# 316 번 인덱스 오류 처리 완료
# 330 번 인덱스 오류 처리 완료
# 332 번 인덱스 오류 처리 완료
# 334 번 인덱스 오류 처리 완료
#  데이터 가공 완료
#
#       ----------    Logistic Regression Result    ----------
#  accuracy  :  0.9552835961402683
#  f1-score  :  0.9561403508771931
#  recall    :  0.9587962962962963
#  precision :  0.9534990791896869
#       ---------- Naive Bayes Classification Result ----------
#  accuracy  :  0.7940691927512356
#  f1-score  :  0.7938751472320378
#  recall    :  0.7800925925925926
#  precision :  0.8081534772182254
#       ---------- RandomForest Classifcation Result ----------
#  accuracy  :  0.8990350670746058
#  f1-score  :  0.9013566337088986
#  recall    :  0.9074074074074074
#  precision :  0.8953860210141618
#
#
#    ----------    [5-Fold] Logistic Regression Result    ----------
#  ========= 1 =========
#  accuracy  :  0.9489291598023064
#  f1-score  :  0.9493582263710618
#  recall    :  0.9518015910154423
#  precision :  0.946927374301676
#  ========= 2 =========
#  accuracy  :  0.9559896446222641
#  f1-score  :  0.9572180279112332
#  recall    :  0.9578754578754579
#  precision :  0.9565614997713763
#  ========= 3 =========
#  accuracy  :  0.9571563088512242
#  f1-score  :  0.9585798816568047
#  recall    :  0.9612049292560475
#  precision :  0.9559691330004539
#  ========= 4 =========
#  accuracy  :  0.9569209039548022
#  f1-score  :  0.9573327115877827
#  recall    :  0.9557728119180633
#  precision :  0.9588977113498365
#  ========= 5 =========
#  accuracy  :  0.9548022598870056
#  f1-score  :  0.9548660084626234
#  recall    :  0.9508426966292135
#  precision :  0.9589235127478754
#  ======== 최종 ========
#  평균검증 정확도   :  0.9547596554235206
#  평균검증 f1-score :  0.9554709711979011
#  평균검증 정밀도   :  0.955499497338845
#  평균검증 재현율   :  0.9554558462342436
#
#
#    ---------- [5-Fold] Naive Bayes Classification Result ----------
#  ========= 1 =========
#  accuracy  :  0.7903036008472581
#  f1-score  :  0.7871984714592788
#  recall    :  0.7711745437529247
#  precision :  0.8039024390243903
#  ========= 2 =========
#  accuracy  :  0.7891268533772653
#  f1-score  :  0.7900656044985942
#  recall    :  0.771978021978022
#  precision :  0.809021113243762
#  ========= 3 =========
#  accuracy  :  0.8024952919020716
#  f1-score  :  0.8026346741943071
#  recall    :  0.7786398904609767
#  precision :  0.8281553398058252
#  ========= 4 =========
#  accuracy  :  0.7984934086629002
#  f1-score  :  0.7970602181128498
#  recall    :  0.7825884543761639
#  precision :  0.8120772946859903
#  ========= 5 =========
#  accuracy  :  0.7921374764595104
#  f1-score  :  0.7886042614316495
#  recall    :  0.7710674157303371
#  precision :  0.8069573738363547
#  ======== 최종 ========
#  평균검증 정확도   :  0.7945113262498011
#  평균검증 f1-score :  0.7931126459393358
#  평균검증 정밀도   :  0.7750896652596848
#  평균검증 재현율   :  0.8120227121192645
#
#
#    ---------- [5-Fold] RandomForest Classifcation Result ----------
#  ========= 1 =========
#  accuracy  :  0.8905624852906566
#  f1-score  :  0.8924358084663427
#  recall    :  0.9026672905942911
#  precision :  0.8824336688014639
#  ========= 2 =========
#  accuracy  :  0.8985643680866087
#  f1-score  :  0.9014406585867826
#  recall    :  0.9024725274725275
#  precision :  0.9004111466423024
#  ========= 3 =========
#  accuracy  :  0.9051318267419962
#  f1-score  :  0.9083048919226393
#  recall    :  0.910999543587403
#  precision :  0.9056261343012704
#  ========= 4 =========
#  accuracy  :  0.89924670433145
#  f1-score  :  0.9020594965675058
#  recall    :  0.9175977653631285
#  precision :  0.8870387038703871
#  ========= 5 =========
#  accuracy  :  0.9027777777777778
#  f1-score  :  0.9044644922507518
#  recall    :  0.9152621722846442
#  precision :  0.8939186099679927
#  ======== 최종 ========
#  평균검증 정확도   :  0.8992566324456979
#  평균검증 f1-score :  0.9017410695588044
#  평균검증 정밀도   :  0.9097998598603988
#  평균검증 재현율   :  0.8938856527166832

# %%
# kor_ratio10_4gram
kor_r10_4g = total_model(kor_ratio10_4gram)
score_result = result_append(score_result, kor_r10_4g)
# Out:
# 264 번 인덱스 오류 처리 완료
# 291 번 인덱스 오류 처리 완료
# 304 번 인덱스 오류 처리 완료
# 316 번 인덱스 오류 처리 완료
# 330 번 인덱스 오류 처리 완료
# 331 번 인덱스 오류 처리 완료
# 332 번 인덱스 오류 처리 완료
# 334 번 인덱스 오류 처리 완료
#  데이터 가공 완료
#
#       ----------    Logistic Regression Result    ----------
#  accuracy  :  0.9717838354854137
#  f1-score  :  0.9723134678554668
#  recall    :  0.9714017815283638
#  precision :  0.9732268670737435
#       ---------- Naive Bayes Classification Result ----------
#  accuracy  :  0.8280726924916308
#  f1-score  :  0.8287687544653488
#  recall    :  0.8157524613220816
#  precision :  0.8422071636011617
#       ---------- RandomForest Classifcation Result ----------
#  accuracy  :  0.9239598278335724
#  f1-score  :  0.926046511627907
#  recall    :  0.93342709798406
#  precision :  0.9187817258883249
#
#
#    ----------    [5-Fold] Logistic Regression Result    ----------
#  ========= 1 =========
#  accuracy  :  0.9681970349115255
#  f1-score  :  0.9684310467600284
#  recall    :  0.967741935483871
#  precision :  0.9691211401425178
#  ========= 2 =========
#  accuracy  :  0.9770444763271162
#  f1-score  :  0.9776847977684797
#  recall    :  0.9785946952070731
#  precision :  0.97677659080353
#  ========= 3 =========
#  accuracy  :  0.9722554412819899
#  f1-score  :  0.9730858468677493
#  recall    :  0.9663594470046083
#  precision :  0.9799065420560747
#  ========= 4 =========
#  accuracy  :  0.9720162640516623
#  f1-score  :  0.9726699369306236
#  recall    :  0.9760900140646976
#  precision :  0.9692737430167597
#  ========= 5 =========
#  accuracy  :  0.9691461372877302
#  f1-score  :  0.9692197566213313
#  recall    :  0.9666825321275583
#  precision :  0.9717703349282296
#  ======== 최종 ========
#  평균검증 정확도   :  0.9717318707720048
#  평균검증 f1-score :  0.9722182769896426
#  평균검증 정밀도   :  0.9710937247775616
#  평균검증 재현율   :  0.9733696701894223
#
#
#    ---------- [5-Fold] Naive Bayes Classification Result ----------
#  ========= 1 =========
#  accuracy  :  0.8187470109995217
#  f1-score  :  0.8173493975903615
#  recall    :  0.8045540796963947
#  precision :  0.8305582761998042
#  ========= 2 =========
#  accuracy  :  0.8335724533715926
#  f1-score  :  0.8353831598864712
#  recall    :  0.8217775709632387
#  precision :  0.8494468494468495
#  ========= 3 =========
#  accuracy  :  0.8222913178665391
#  f1-score  :  0.8233895887806039
#  recall    :  0.7981566820276498
#  precision :  0.8502700049091801
#  ========= 4 =========
#  accuracy  :  0.8210954317149007
#  f1-score  :  0.8235849056603773
#  recall    :  0.8185654008438819
#  precision :  0.8286663502610346
#  ========= 5 =========
#  accuracy  :  0.82013872279359
#  f1-score  :  0.818269695505075
#  recall    :  0.8058067586863399
#  precision :  0.8311242022582229
#  ======== 최종 ========
#  평균검증 정확도   :  0.8231689873492289
#  평균검증 f1-score :  0.8235953494845777
#  평균검증 정밀도   :  0.8097720984435011
#  평균검증 재현율   :  0.8380131366150183
#
#
#    ---------- [5-Fold] RandomForest Classifcation Result ----------
#  ========= 1 =========
#  accuracy  :  0.9189383070301291
#  f1-score  :  0.919952774498229
#  recall    :  0.9240986717267552
#  precision :  0.9158439116125999
#  ========= 2 =========
#  accuracy  :  0.9256336681013869
#  f1-score  :  0.9284564067172763
#  recall    :  0.9390414146114472
#  precision :  0.9181073703366697
#  ========= 3 =========
#  accuracy  :  0.9203539823008849
#  f1-score  :  0.9234306737180961
#  recall    :  0.9253456221198156
#  precision :  0.9215236346948141
#  ========= 4 =========
#  accuracy  :  0.9220282229131787
#  f1-score  :  0.9249539594843461
#  recall    :  0.9418659165494608
#  precision :  0.9086386250565355
#  ========= 5 =========
#  accuracy  :  0.9146137287730208
#  f1-score  :  0.9159406639981162
#  recall    :  0.9257496430271299
#  precision :  0.9063373718546133
#  ======== 최종 ========
#  평균검증 정확도   :  0.9203135818237203
#  평균검증 f1-score :  0.9225468956832128
#  평균검증 정밀도   :  0.9312202536069218
#  평균검증 재현율   :  0.9140901827110465

# %% [markdown]
# ### score 파일 저장

# %%
# 나온 결과 저장
score_result.to_csv('result_final.csv')
