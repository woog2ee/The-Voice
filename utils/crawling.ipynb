# %% [markdown]
# ### 기본 세팅

# %%
import time
import pandas as pd
import re
import ast

from selenium import webdriver
from kss import split_sentences

# %% [markdown]
# ### 보이스피싱 텍스트 크롤링

# %%
def get_대출사기형_info():
    
    list_url     = []     # 주소 리스트
    list_content = []     # 본문 리스트
    
    
    # 드라이버 실행
    driver = webdriver.Chrome('chromedriver.exe')
    driver.implicitly_wait(3)
    sleeptime = 0.5     # 프로세스 일시 정지 시간


    # 페이지를 돌며 게시글 주소 크롤링
    for page in range(1, 20, 1):
        try:
            # 페이지 이동
            driver.get(f'https://phishing-keeper.fss.or.kr/fss/vstop/bbs/list.jsp?category=100128&url=/fss/vstop/1436425918273&bbsid=1436425918273&page={page}')
            time.sleep(sleeptime)


            # 주소 크롤링
            current = driver.find_elements_by_css_selector('#contents > div.contents_in > table > tbody > tr > td.t_al > a')
            for url in current:
                list_url.append(url.get_attribute('href'))
        except:
            pass


    # 게시글을 돌며 텍스트 크롤링
    for url in list_url:
        try:
            # 게시물 이동
            driver.get(url)
            time.sleep(sleeptime)


            # 텍스트 크롤링
            cur_content = []
            current = driver.find_elements_by_css_selector('#contents > div > table > tbody > tr > td > div > p')

            # 게시글에 텍스트가 없는 경우
            if len(current) == 0:
                list_content.append(cur_content)
                continue

            # 게시글에 텍스트가 있는 경우
            for sentence in current:
                cur_content.append(sentence.text)
            list_content.append(cur_content)
        except:
            pass
    driver.close()


    voicephishing_대출사기형 = pd.DataFrame({'주소': list_url, '내용': list_content})
    return voicephishing_대출사기형

# %%
def get_수사기관사칭형_info():
    
    list_url     = []     # 주소 리스트
    list_content = []     # 본문 리스트

    
    # 드라이버 실행
    driver = webdriver.Chrome('chromedriver.exe')
    driver.implicitly_wait(3)
    sleeptime = 0.5     # 프로세스 일시 정지 시간
    

    # 페이지를 돌며 게시글 주소 크롤링
    for page in range(1, 24, 1):
        try:
            # 페이지 이동
            driver.get(f'https://phishing-keeper.fss.or.kr/fss/vstop/bbs/list.jsp?category=100125&url=/fss/vstop/1436425918273&bbsid=1436425918273&page={page}')
            time.sleep(sleeptime)


            # 주소 크롤링
            current = driver.find_elements_by_css_selector('#contents > div.contents_in > table > tbody > tr > td.t_al > a')
            for url in current:
                list_url.append(url.get_attribute('href'))
        except:
            pass


    # 게시글을 돌며 텍스트 크롤링
    for url in list_url:
        try:
            # 게시물 이동
            driver.get(url)
            time.sleep(sleeptime)


            # 텍스트 크롤링
            cur_content = []
            current = driver.find_elements_by_css_selector('#contents > div > table > tbody > tr > td > div > p')

            # 게시글에 텍스트가 없는 경우
            if len(current) == 0:
                list_content.append(cur_content)
                continue

            # 게시글에 텍스트가 있는 경우
            for sentence in current:
                cur_content.append(sentence.text)
            list_content.append(cur_content)
        except:
            pass
    driver.close()


    voicephishing_수사기관사칭형 = pd.DataFrame({'주소': list_url, '내용': list_content})
    return voicephishing_수사기관사칭형

# %%
voicephishing_대출사기형 = get_대출사기형_info()
#voicephishing_대출사기형 = pd.read_csv('voicephishing_대출사기형.csv', index_col=0)

# %%
voicephishing_대출사기형.head(10)
# Out:
#                                                   주소  \
# 0  https://phishing-keeper.fss.or.kr/fss/vstop/bb...
# 1  https://phishing-keeper.fss.or.kr/fss/vstop/bb...
# 2  https://phishing-keeper.fss.or.kr/fss/vstop/bb...
# 3  https://phishing-keeper.fss.or.kr/fss/vstop/bb...
# 4  https://phishing-keeper.fss.or.kr/fss/vstop/bb...
# 5  https://phishing-keeper.fss.or.kr/fss/vstop/bb...
# 6  https://phishing-keeper.fss.or.kr/fss/vstop/bb...
# 7  https://phishing-keeper.fss.or.kr/fss/vstop/bb...
# 8  https://phishing-keeper.fss.or.kr/fss/vstop/bb...
# 9  https://phishing-keeper.fss.or.kr/fss/vstop/bb...
#
#                                                   내용
# 0                                                 []
# 1                                                 []
# 2                                                 []
# 3                                                 []
# 4                                                 []
# 5                                                 []
# 6  ['피해자 : 여보세요', '사기범 : 네 (삐-) (삐-) 님', '피해자 : 예...
# 7  ['피해자:여보세요', '사기범:안녕하세요 고객님 김종현 대리입니다', '피해자:아...
# 8  ['사기범:네 여보세요?', '피해자:여보세요', '사기범:네 ㅇㅇ 맞으신가요?',...
# 9  ['피해자:네', '사기범:네 여보세요', '피해자:뭐 어디세요?', '사기범:아 ...

# %%
voicephishing_수사기관사칭형 = get_수사기관사칭형_info()
#voicephishing_수사기관사칭형 = pd.read_csv('voicephishing_수사기관사칭형.csv', index_col=0)

# %%
voicephishing_수사기관사칭형.head(10)
# Out:
#                                                   주소  \
# 0  https://phishing-keeper.fss.or.kr/fss/vstop/bb...
# 1  https://phishing-keeper.fss.or.kr/fss/vstop/bb...
# 2  https://phishing-keeper.fss.or.kr/fss/vstop/bb...
# 3  https://phishing-keeper.fss.or.kr/fss/vstop/bb...
# 4  https://phishing-keeper.fss.or.kr/fss/vstop/bb...
# 5  https://phishing-keeper.fss.or.kr/fss/vstop/bb...
# 6  https://phishing-keeper.fss.or.kr/fss/vstop/bb...
# 7  https://phishing-keeper.fss.or.kr/fss/vstop/bb...
# 8  https://phishing-keeper.fss.or.kr/fss/vstop/bb...
# 9  https://phishing-keeper.fss.or.kr/fss/vstop/bb...
#
#                                                   내용
# 0                                                 []
# 1                                                 []
# 2                                                 []
# 3                                                 []
# 4  ['사기범 : 아 서울 중앙 지검 첨단 범죄 수사 일부 이희나 수사관입니다. 본 사...
# 5  ['피해자 : 여보세요', '사기범 : 여보세요 OOO씨 혹시 맞습니까?', '피해...
# 6  ['사기범 : 여보세요', '피해자 : 네', '사기범 : 네 안녕하십니까. 혹시 ...
# 7  ['사기범 : 수고하십니다. 여기는 서울 중앙 지검이고요', '피해자 : 네', '...
# 8  ['사기범 : 어 이름은 김호철이고 태어난 곳은 전라도 광주, 올해로 사십세된 남성...
# 9  ['사기범 : 네 여보세요', '피해자 : 네 네', '사기범 : 아 아 다른 게 ...

# %% [markdown]
# ### 텍스트 전처리

# %%
# 텍스트 있는 경우만 남김
voicephishing_대출사기형_text = list(voicephishing_대출사기형['내용'])
voicephishing_대출사기형_text = [i for i in voicephishing_대출사기형_text if i != '[]']
len_대출사기형_text = len(voicephishing_대출사기형_text)
print(f' 대출사기형 보이스피싱 텍스트 건수: {len_대출사기형_text}')

voicephishing_수사기관사칭형_text = list(voicephishing_수사기관사칭형['내용'])
voicephishing_수사기관사칭형_text = [i for i in voicephishing_수사기관사칭형_text if i != '[]']
len_수사기관사칭형_text = len(voicephishing_수사기관사칭형_text)
print(f' 수사기관사칭형 보이스피싱 텍스트 건수: {len_수사기관사칭형_text}')


# 문자열의 리스트화
for i in range(len_대출사기형_text):
    cur_text = voicephishing_대출사기형_text[i]
    cur_text = ast.literal_eval(cur_text)
    voicephishing_대출사기형_text[i] = cur_text
    
for i in range(len_수사기관사칭형_text):
    cur_text = voicephishing_수사기관사칭형_text[i]
    cur_text = ast.literal_eval(cur_text)
    voicephishing_수사기관사칭형_text[i] = cur_text
# Out:
#  대출사기형 보이스피싱 텍스트 건수: 135
#  수사기관사칭형 보이스피싱 텍스트 건수: 6

# %%
# 피해자/사기범 명칭 제거
for i in range(len_대출사기형_text):
    cur_text = voicephishing_대출사기형_text[i]
    
    for j in range(len(cur_text)):
        # 피해자 명칭 제거
        if ('피해자:' in cur_text[j]) or ('피해자 : ' in cur_text[j]):
            cur_text[j] = re.sub(r'피해자:', '', cur_text[j])
            cur_text[j] = re.sub(r'피해자 : ', '', cur_text[j])
            voicephishing_대출사기형_text[i][j] = cur_text[j]
            continue
            
        # 사기범 명칭 제거
        if ('사기범:' in cur_text[j]) or ('사기범 : ' in cur_text[j]):
            cur_text[j] = re.sub(r'사기범:', '', cur_text[j])
            cur_text[j] = re.sub(r'사기범 : ', '', cur_text[j])
            voicephishing_대출사기형_text[i][j] = cur_text[j]
                
                
for i in range(len_수사기관사칭형_text):
    cur_text = voicephishing_수사기관사칭형_text[i]
    
    for j in range(len(cur_text)):
        # 피해자 명칭 제거
        if ('피해자:' in cur_text[j]) or ('피해자 : ' in cur_text[j]):
            cur_text[j] = re.sub(r'피해자:', '', cur_text[j])
            cur_text[j] = re.sub(r'피해자 : ', '', cur_text[j])
            voicephishing_수사기관사칭형_text[i][j] = cur_text[j]
            continue
            
        # 사기범 명칭 제거
        if ('사기범:' in cur_text[j]) or ('사기범 : ' in cur_text[j]):
            cur_text[j] = re.sub(r'사기범:', '', cur_text[j])
            cur_text[j] = re.sub(r'사기범 : ', '', cur_text[j])
            voicephishing_수사기관사칭형_text[i][j] = cur_text[j]

# %%
# 문장 분리
for i in range(len_대출사기형_text):
    cur_text = voicephishing_대출사기형_text[i]
    splited_text = []
    
    for j in range(len(cur_text)):       
        # 문장 분리 후 길이 저장
        splited = split_sentences(cur_text[j])
        len_splited = len(splited)
        
        # 길이가 1이면 바로 추가함
        if len_splited == 1:
            splited_text.append(cur_text[j])
        # 길이가 1이 아니면 나눠서 추가함
        else:
            for k in range(len_splited):
                splited_text.append(splited[k])
            
    # 분리한 문장으로 대체
    voicephishing_대출사기형_text[i] = splited_text
    
    
for i in range(len_수사기관사칭형_text):
    cur_text = voicephishing_수사기관사칭형_text[i]
    splited_text = []
    
    for j in range(len(cur_text)):       
        # 문장 분리 후 길이 저장
        splited = split_sentences(cur_text[j])
        len_splited = len(splited)
        
        # 길이가 1이면 바로 추가함
        if len_splited == 1:
            splited_text.append(cur_text[j])
        # 길이가 1이 아니면 나눠서 추가함
        else:
            for k in range(len_splited):
                splited_text.append(splited[k])
            
    # 분리한 문장으로 대체
    voicephishing_수사기관사칭형_text[i] = splited_text

# %%
# 욕설 제거
for i in range(len_대출사기형_text):
    cur_text = voicephishing_대출사기형_text[i]
    
    for j in range(len(cur_text)):                      
        # 욕설 이후 제거
        if 'xx' in cur_text[j]:
            del voicephishing_대출사기형_text[i][j:]
            break
                   
                
for i in range(len_수사기관사칭형_text):
    cur_text = voicephishing_수사기관사칭형_text[i]
    
    for j in range(len(cur_text)):                     
        # 욕설 이후 제거
        if 'xx' in cur_text[j]:
            del voicephishing_수사기관사칭형_text[i][j:]
            break

# %% [markdown]
# ### 파일 저장

# %%
# 문장당 카운트 횟수
countsent_대출사기형 = 0
for i in range(len_대출사기형_text):
    countsent_대출사기형 += len(voicephishing_대출사기형_text[i])
print(f' 대출사기형 사기범 문장 개수: {countsent_대출사기형}')
    
countsent_수사기관사칭형 = 0
for i in range(len_수사기관사칭형_text):
    countsent_수사기관사칭형 += len(voicephishing_수사기관사칭형_text[i])
print(f' 수사기관사칭형 사기범 문장 개수: {countsent_수사기관사칭형}')
# Out:
#  대출사기형 사기범 문장 개수: 10107
#  수사기관사칭형 사기범 문장 개수: 686

# %%
# 파일 통합
voicephishing_전체_text = voicephishing_대출사기형_text + voicephishing_수사기관사칭형_text
len_전체_text = len(voicephishing_전체_text)
print(f' 보이스피싱 전체 사건 개수: {len_전체_text}')

countsent_전체 = 0
for i in range(len_전체_text):
    countsent_전체 += len(voicephishing_전체_text[i])
print(f' 전체 문장 개수: {countsent_전체}')
# Out:
#  보이스피싱 전체 사건 개수: 141
#  전체 문장 개수: 10793

# %%
voicephishing_전체 = pd.DataFrame({'내용': voicephishing_전체_text})
voicephishing_전체.head(10)
# Out:
#                                                   내용
# 0  [여보세요, 네 (삐-) (삐-) 님, 예 예, 어저께 통화했던 최영환입니다, 아 ...
# 1  [여보세요, 안녕하세요, 고객님 김종현 대리입니다, 아네 대리님, 고객님 연락이 너...
# 2  [네 여보세요?, 여보세요, 네 ㅇㅇ 맞으신가요?, 네네, 네 안녕하세요, 여기 스...
# 3  [네, 네 여보세요, 뭐 어디세요?, 아 네 안녕하세요, 저희 그 하나캐피탈에서 연...
# 4  [여보세요?, 네 여보세요, 네, 아 네 고객님 설명 도움주렸던 하나 캐피탈 김민기...
# 5  [네 웰컴저축은행입니다, 네 문자받고 전화드렸는데요, 아 네 문자 언제받으셨어요?,...
# 6  [여보세요?, 네 2가지 방법이 있는데 첫 번째는 국민은행에 고객님 적금이나 정기 ...
# 7  [여보세요, 네 ㅇㅇ고객님 되시죠?, 네, 안녕하세요, 저희 kb캐피탈입니다 고객님...
# 8  [네 감사합니다, ㅇㅇㅇ 대리 있나요?, ㅇㅇㅇ대리요?, 연결이요?, 잠시 외근나가...
# 9  [네 감사합니다, ㅇㅇㅇ 대리 있나요?, ㅇㅇㅇ대리요?, 연결이요?, 잠시 외근나가...

# %%
# 파일 저장
voicephishing_전체.to_csv('voicephishing_전체.csv')
